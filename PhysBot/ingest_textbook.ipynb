# %%
import os
import fitz  # PyMuPDF
from PyPDF2 import PdfMerger
import utils
from tqdm import tqdm
import re
from openai import OpenAI
import json
import pdfplumber
import nltk

nltk.download("punkt")
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
from dotenv import load_dotenv
# Out:
# [nltk_data] Downloading package punkt to /home/jd_wsl0/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/jd_wsl0/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
import logging

logging.basicConfig(level=logging.INFO)

# %%
import importlib
import utils
importlib.reload(utils)
# Out:
# [nltk_data] Downloading package punkt to /home/jd_wsl0/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/jd_wsl0/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# <module 'utils' from '/home/jd_wsl0/llm-z-camp/PhysBot/utils.py'>

# %%
# Define input folder and output PDF file
pdf_folder = "data/chapters/"  # Replace with actual folder path
output_pdf = "data/Bare_Essentials_Only.pdf"

# essentials = utils.extract_first_page(pdf_folder, output_pdf)
# Out:
# Bare Essentials pages saved to data/Bare_Essentials_Only.pdf

# %%
# Load environment variables from .env
load_dotenv(".env")  # Specify the correct path if in a higher-level folder

# Retrieve OpenAI API key from the environment
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if not OPENAI_API_KEY:
    raise ValueError("OPENAI_API_KEY is not set. Check your .env file.")

# %%
# Run processing
pdf_path = "data/Bare_Essentials_Only.pdf"  # Replace with actual path
output_json_path = "data/json/bare_essentials_concepts.json"
concepts_json = utils.process_bare_essentials(pdf_path, output_json_path)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"                 | 0/35 [00:00<?, ?section/s]
# INFO:root:Raw OpenAI response: [{"concept": "Physics", "definition": "The study of matter, energy, and their interactions.", "equation": "", "notes": []}, {"concept": "Four Fundamental Interactions", "definition": "Interactions that describe the universe with different relative strengths.", "equation": "", "notes": ["Strong Nuclear Interaction: Short-range interaction between quarks and gluons responsible for keeping quarks together in nucleons, and nucleons together in nuclei.", "Weak Nuclear Interaction: Short-range interaction responsible for nuclear radioactivity.", "Gravitational Interaction: Long-range, attractive interaction between massive particles.", "Electromagnetic Interaction: Long-range interaction between electrically charged particles."]}, {"concept": "Standard Model", "definition": "The most widely accepted fundamental model for our universe.", "equation": "", "notes": ["Composed of three basic types of particles: Fermions and Bosons.", "Fermions: Subatomic particles with half-integer spin.", "Quarks: Experience all fundamental interactions and combine to form massive particles such as protons and neutrons.", "Leptons: Do not experience the strong interaction. Often products of nuclear reactions mediated by the weak interaction.", "Bosons: Subatomic particles with integer spin. Carry information about interactions between particles.", "Each fundamental interaction has at least one boson: Photons (electromagnetic), Gluons (strong nuclear), W and Z bosons (weak nuclear), Graviton (gravity - theoretical).", "Problems with the standard model lead to extensions including string theory and attempts to explain dark matter and dark energy."]}, {"concept": "Significant Figures", "definition": "Used to determine the precision with which a measurement or calculation is made.", "equation": "", "notes": ["Generally, two or three significant figures are used in Physics I and II."]}, {"concept": "Fundamental Quantities in Physics", "definition": "Basic units of measurement in physics.", "equation": "", "notes": ["Energy (J or eV)", "Mass (kg, amu or eV/c2)", "Length (m)", "Time (s)"]}, {"concept": "SI Prefixes", "definition": "Used to describe the scale of quantities in physics.", "equation": "", "notes": []}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"         | 1/35 [00:10<06:09, 10.86s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Nuclear Symbol", "definition": "The nuclear symbol for an atom with chemical symbol X is described by its number of protons (Z), the total number of nucleons (A).", "equation": "", "notes": ["The chemical symbol (X) and the number of protons are redundant; however, in physics, both are often expressed for ease of use.", "The number of neutrons in a nucleus is given by the neutron number, N = A – Z."]}, {"concept": "Nuclear Radius", "definition": "This equation describes the radius of a nucleus, r, with nuclear number, A.", "equation": "r = r0A^(1/3)", "notes": ["r0 = 1.25 fm."]}, {"concept": "Neutral Atom", "definition": "An electrically neutral atom has the same number of electrons as protons with the electrons in shells around the nucleus of the atom.", "equation": "", "notes": []}, {"concept": "Ion", "definition": "An ion is an atom or molecule where the number of electrons does not match the number of protons.", "equation": "", "notes": []}, {"concept": "Macroscopic Interactions", "definition": "Macroscopic interactions describe the results of the fundamental interactions that we see in everyday life. Except for the macroscopic gravitational interaction, all macroscopic interactions are a result of the fundamental electromagnetic interaction.", "equation": "", "notes": []}, {"concept": "System", "definition": "A system is a part of the universe being studied.", "equation": "", "notes": ["An isolated system is a system of objects that we can consider to undergo no interactions with objects outside of the system.", "The environment is the area outside of the system which is ignored except for specific interactions with the system."]}, {"concept": "Model", "definition": "In physics, a model is a set of rules and assumptions used to define a problem.", "equation": "", "notes": ["Two important models used in this course are classical mechanics and special relativity."]}, {"concept": "Interactions", "definition": "Interactions come in three forms: fundamental interactions, mechanical interactions, and microscopic interactions.", "equation": "", "notes": ["Fundamental interactions: The four fundamental interactions.", "Mechanical interactions: Interactions that lead to a change in motion.", "Microscopic interactions: Interactions that lead to a non-mechanical, macroscopic change (change in temperature, phase, shape, etc.)."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"         | 2/35 [00:21<06:02, 10.97s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Scalar", "definition": "Scalars are quantities that only require a number to describe them fully.", "equation": "", "notes": []}, {"concept": "Vector", "definition": "Vectors are quantities that require both a magnitude and direction to be fully described.", "equation": "", "notes": ["A vector can be described in terms of its components relative to a set of axes."]}, {"concept": "Vector Notation", "definition": "Defines the vector notation for a vector with components along x-, y-, and z-axes, respectively.", "equation": "𝑎⃗= [𝑎x, 𝑎y, 𝑎z] = 𝑎x𝚤̂ + 𝑎y𝚥̂ + 𝑎z𝑘෠", "notes": ["The choice of 𝚤̂, 𝚥̂, and 𝑘෠ for the unit-vector notation is arbitrary; however, these most often correspond to the x-, y-, and z-axes, respectively."]}, {"concept": "Vector Components", "definition": "Defines the components of a vector based on trigonometric relationships to its magnitude and angle.", "equation": "𝑎x = |𝑎⃗| cos 𝜃x→y, 𝑎y = |𝑎⃗| sin 𝜃x→y", "notes": ["|𝑎⃗| is the magnitude of vector 𝑎⃗.", "These equations are extensible to any plane. For example, in the y-z plane with angle measured off of y-axis, 𝑎y= |𝑎⃗| cos 𝜃y→z, 𝑎z= |𝑎⃗| sin 𝜃y→z."]}, {"concept": "Magnitude/Angle Notation", "definition": "Describes a vector in terms of its magnitude and direction relative to a given axis.", "equation": "|𝑎⃗| = √(𝑎x² + 𝑎y²), 𝜃x→y = atan(𝑎y/𝑎x)", "notes": ["The angle, 𝜃x→y, is measured from the positive x-axis towards the positive y-axis.", "These equations are extensible to any plane. For example, the angle of a vector in the y-z plane, measured from the y-axis towards the z-axis is 𝜃y→z = atan(𝑎z/𝑎y)."]}, {"concept": "Three-Dimensional Vector Description", "definition": "Defines a three-dimensional vector using components and angles similar to two-dimensional vectors.", "equation": "𝑎⃗ = [𝑎x, 𝑎y, 𝑎z] = 𝑎x𝚤̂ + 𝑎y𝚥̂ + 𝑎z𝑘෠, |𝑎⃗| = √(𝑎x² + 𝑎y² + 𝑎z²), 𝜃x→y = atan(𝑎y/𝑎x), 𝜃xy→z = atan(𝑎z/√(𝑎x² + 𝑎y²))", "notes": ["𝜃xy→z is the angle of inclination, an angle measured from the xy-plane towards the z-axis.", "Components: 𝑎x= |𝑎⃗| cos 𝜃x→y cos 𝜃xy→z, 𝑎y= |𝑎⃗| sin 𝜃x→y cos 𝜃xy→z, 𝑎z= |𝑎⃗| sin 𝜃xy→z."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"         | 3/35 [00:48<09:44, 18.27s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Energy", "definition": "A fundamental quantity that particles can possess. The energy of a particle can be made up of rest-mass energy, kinetic energy, and potential energy. The total energy of a particle is the sum of each of these energies.", "equation": "Not provided explicitly in the text.", "notes": ["Rest-mass, kinetic, and total energy equations are mentioned but not provided."]}, {"concept": "Conservation of Energy (Isolated System)", "definition": "The total energy contained in an isolated system does not change.", "equation": "𝚫𝑬= 𝟎", "notes": ["An isolated system is defined as a system that does not interact with its surroundings."]}, {"concept": "Energy Transfer Forms", "definition": "Energy can be transferred into or out of a system in various forms such as heat, thermodynamic work, and mechanical work.", "equation": "", "notes": ["Heat is due to temperature differences.", "Thermodynamic work is due to mechanical and microscopic interactions, not temperature differences.", "Mechanical work is a subset of thermodynamic work, related to mechanical interactions."]}, {"concept": "Momentum", "definition": "The momentum of an individual particle is given by the product of its mass, velocity, and the Lorentz factor.", "equation": "𝑝⃗= 𝛾𝑚𝑣⃗", "notes": []}, {"concept": "Conservation of Momentum (Isolated System)", "definition": "The total momentum contained in an isolated system does not change.", "equation": "𝚫𝒑ሬሬ⃗= 𝟎", "notes": ["An isolated system is defined as a system that does not interact with its surroundings."]}, {"concept": "Newton’s Laws", "definition": "A set of three fundamental laws that describe motion and interactions of particles.", "equation": "", "notes": ["Newton’s 1st Law: The velocity of a particle does not change when it is not undergoing any interactions.", "Newton’s 2nd Law: The net force on an object is equal to the rate of change of its momentum.", "Newton’s 3rd Law: Forces between two interacting objects are equal in magnitude and opposite in direction.", "Newton’s Laws apply to individual particles, unlike conservation laws which deal with entire systems."]}, {"concept": "Newton’s Second Law", "definition": "The equation relates the net force on an object to the rate of change of the object's momentum.", "equation": "𝐅⃗𝐧𝐞𝐭= 𝒅𝒑ሬሬ⃗ 𝒅𝒕", "notes": ["When the mass of an object moving at non-relativistic speeds is constant, the equation reduces to 𝑚𝑎⃗."]}]
# WARNING:root:Potential unrecognized equation format: 𝚫𝒑ሬሬ⃗= 𝟎
# WARNING:root:Potential unrecognized equation format: \mathbf{F}𝐧𝐞𝐭= 𝒅𝒑ሬሬ⃗ 𝒅𝒕
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"         | 4/35 [01:01<08:21, 16.17s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Position Vector", "definition": "The position of an object is its vector relationship to a reference point (usually the origin of a coordinate system).", "equation": "𝒓𝒓ሬ⃗ = [𝒓𝒓𝒙𝒙, 𝒓𝒓𝒚𝒚, 𝒓𝒓𝒛𝒛]", "notes": ["This vector must be relative to some coordinate system origin.", "The SI unit for position is the meter (m)."]}, {"concept": "Displacement Vector", "definition": "Displacement is the vector change in position of an object.", "equation": "𝚫𝚫𝒓𝒓ሬ⃗ = [𝚫𝚫𝒓𝒓𝒙𝒙, 𝚫𝚫𝒓𝒓𝒚𝒚, 𝚫𝚫𝒓𝒓𝒛𝒛]", "notes": ["Δ𝑟𝑟⃗ = 𝑟𝑟⃗2 − 𝑟𝑟⃗1, meaning that only the final and initial positions are required for the displacement."]}, {"concept": "Velocity", "definition": "Velocity is the time rate of change of position.", "equation": "𝒗𝒗ሬሬ⃗ = 𝒅𝒅𝒓𝒓ሬ⃗ / 𝒅𝒅𝒅𝒅 = [𝒅𝒅𝒓𝒙𝒙 / 𝒅𝒅𝒅𝒅, 𝒅𝒅𝒓𝒓𝒚𝒚 / 𝒅𝒅𝒅𝒅, 𝒅𝒅𝒓𝒓𝒛𝒛 / 𝒅𝒅𝒅𝒅]", "notes": ["The SI unit for velocity and speed is m/s.", "Instantaneous speed can be found as the magnitude of the velocity vector.", "The average velocity of an object can be found as 𝑣𝑣⃗𝑎𝑎𝑎𝑎𝑎𝑎= Δ𝑟𝑟⃗/Δ𝑡𝑡."]}, {"concept": "Acceleration", "definition": "Acceleration is the time rate of change of velocity.", "equation": "𝒂𝒂ሬሬ⃗ = 𝒅𝒅𝒗𝒗ሬሬ⃗ / 𝒅𝒅𝒅𝒅 = [𝒅𝒅𝒗𝒙𝒙 / 𝒅𝒅𝒅𝒅, 𝒅𝒅𝒗𝒚𝒚 / 𝒅𝒅𝒅𝒅, 𝒅𝒅𝒗𝒛𝒛 / 𝒅𝒅𝒅𝒅]", "notes": ["The SI unit of acceleration is m/s².", "The average acceleration of an object can be found as 𝑎𝑎⃗𝑎𝑎𝑎𝑎𝑎𝑎= Δ𝑣𝑣⃗/Δ𝑡𝑡.", "Acceleration is always a vector. If you are discussing the scalar form of acceleration it is the magnitude of the acceleration."]}, {"concept": "Kinetic Energy", "definition": "Kinetic Energy is the energy of motion, and depends only on an object’s mass and speed.", "equation": "𝑲𝑲 = (𝜸𝜸−𝟏𝟏)𝒎𝒎𝒄𝒄^2", "notes": ["𝜸𝜸 = (1−𝒗𝒗^2/𝒄𝒄^2 )^(−1/2)"]}, {"concept": "Kinetic Energy (Classical Limit)", "definition": "This equation describes the classical kinetic energy of an object of mass, 𝑚𝑚 and speed, 𝑣𝑣.", "equation": "𝑲𝑲 = 1/2 𝒎𝒎 𝒗𝒗^2", "notes": ["This equation can be used when 𝑣𝑣 < ~3×10^6 m/s.", "𝑣𝑣^2 = 𝑣𝑣⃗⋅𝑣𝑣⃗."]}]
# WARNING:root:Potential unrecognized equation format: 𝒓𝒓ሬ⃗ = \begin{bmatrix} 𝒓𝒓𝒙𝒙 \\  𝒓𝒓𝒚𝒚 \\  𝒓𝒓𝒛𝒛 \end{bmatrix}
# WARNING:root:Potential unrecognized equation format: 𝚫𝚫𝒓𝒓ሬ⃗ = \begin{bmatrix} 𝚫𝚫𝒓𝒓𝒙𝒙 \\  𝚫𝚫𝒓𝒓𝒚𝒚 \\  𝚫𝚫𝒓𝒓𝒛𝒛 \end{bmatrix}
# WARNING:root:Potential unrecognized equation format: 𝒗𝒗ሬሬ⃗ = 𝒅𝒅𝒓𝒓ሬ⃗ / 𝒅𝒅𝒅𝒅 = \begin{bmatrix} 𝒅𝒅𝒓𝒙𝒙 / 𝒅𝒅𝒅𝒅 \\  𝒅𝒅𝒓𝒓𝒚𝒚 / 𝒅𝒅𝒅𝒅 \\  𝒅𝒅𝒓𝒓𝒛𝒛 / 𝒅𝒅𝒅𝒅 \end{bmatrix}
# WARNING:root:Potential unrecognized equation format: 𝒂𝒂ሬሬ⃗ = 𝒅𝒅𝒗𝒗ሬሬ⃗ / 𝒅𝒅𝒅𝒅 = \begin{bmatrix} 𝒅𝒅𝒗𝒙𝒙 / 𝒅𝒅𝒅𝒅 \\  𝒅𝒅𝒗𝒚𝒚 / 𝒅𝒅𝒅𝒅 \\  𝒅𝒅𝒗𝒛𝒛 / 𝒅𝒅𝒅𝒅 \end{bmatrix}
# WARNING:root:Potential unrecognized equation format: 𝑲𝑲 = (𝜸\gamma - 1𝟏)𝒎𝒎𝒄𝒄^2
# WARNING:root:Potential unrecognized equation format: 𝑲𝑲 = \frac{1}{2} 𝒎𝒎 𝒗𝒗^2
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"         | 5/35 [01:24<09:19, 18.64s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Gravitational Potential Energy", "definition": "This equation describes the gravitational potential energy, Ug, stored between two masses, m1 and m2, whose centers of mass are separated by a distance, r12.", "equation": "Ug = -G * m1 * m2 / r12", "notes": ["The reference frame for this equation is set so that Ug = 0 when r12 = ∞.", "The constant of proportionality, G, is known as the universal gravitational constant and has a value G = 6.67 x 10^-11 m^3 kg^-1 s^-2."]}, {"concept": "Gravitational Field", "definition": "The equation describes the gravitational field, g⃗, of a large, spherical object of mass, m, a distance r12 from the center of mass of the object.", "equation": "g⃗ = -G * m / r12² r̂12", "notes": ["This equation assumes we are outside the radius of the object.", "The reference frame for this equation is set so that g⃗ = 0 when r12 = ∞."]}, {"concept": "Gravitational Field Strength", "definition": "The gravitational field strength, g, is the magnitude of the gravitational field, |g⃗|, and is always a positive number.", "equation": "g = 9.80 m/s² near the surface of the Earth", "notes": []}, {"concept": "Gravitational Potential Energy (approximation near large body)", "definition": "This equation describes the gravitational potential energy of a mass, m, in a gravitational field strength, g, and height h.", "equation": "Ug = m * g * h", "notes": ["The reference frame for this equation is arbitrary and must be kept consistent for a given system.", "In order to use this approximation, g must be approximately constant over all values of h for a given system; therefore Δh must be much smaller than the radius of the large body."]}, {"concept": "Conservation of Energy (COE)", "definition": "COE can be used to solve problems with gravitational potential energy and kinetic energy.", "equation": "", "notes": []}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"         | 6/35 [01:36<07:49, 16.19s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Potential Energy Diagram", "definition": "A graphical representation that shows how the potential energy of an object changes with position.", "equation": "", "notes": ["Allows determination of where the object is allowed to be in space when total energy is included.", "Helps visualize how the speed of the object changes at different positions based on total energy, potential energy, and conservation of energy."]}, {"concept": "Conservation of Energy", "definition": "A principle stating that the total energy of an isolated system remains constant over time.", "equation": "K(x) = E - U(x)", "notes": ["K(x) is the kinetic energy, E is the total energy, and U(x) is the potential energy."]}, {"concept": "Elastic Potential Energy", "definition": "The energy stored when an object, like a spring, is displaced from its equilibrium position.", "equation": "Us = 1/2 ks |x⃗ - x⃗0|^2", "notes": ["This equation describes the elastic potential energy Us in terms of the stiffness (spring constant) ks and the displacement from equilibrium x - x0.", "This equation is valid for systems that store energy according to the linear version of Hooke’s law.", "The coordinate system can often be set up so that x0 = 0.", "The spring constant ks has units of either J/m^2 or N/m.", "Bonds between atoms act like springs in terms of energy storage."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"         | 7/35 [01:45<06:33, 14.06s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Temperature", "definition": "Temperature is defined in terms of the average translational kinetic energy of a group of molecules.", "equation": "K_avg = (3/2) * k_b * T", "notes": ["k_b is the Boltzmann constant and has value k_b = 1.381x10^-23 J/K = 8.617x10^-5 eV/K", "T must be measured in Kelvin."]}, {"concept": "Internal Energy", "definition": "The internal energy, U, of a substance describes all of the microscopic energy stored in motion and bonds.", "equation": "", "notes": ["Internal energy is composed of thermal energy and latent energy."]}, {"concept": "Thermal Energy of Gases", "definition": "This equation defines the thermal energy of a system in terms of the number of particles in the system, the degrees of freedom for the system, and the energy for each degree of freedom.", "equation": "U_Th = (Nf/2) * k_b * T", "notes": ["f = 3 for an ideal monatomic gas and simple solids", "f = 5 for diatomic gases including rotation", "f = 7 for diatomic gases including rotation and vibration"]}, {"concept": "Change in Thermal Energy", "definition": "This equation relates the change in thermal energy of a system to its mass, specific heat, and change in temperature.", "equation": "ΔU_Th = mcΔT", "notes": ["ΔT can be in Kelvin or Celsius since both scales have the same gradations."]}, {"concept": "Latent Energy", "definition": "Latent energy describes how energy is stored between molecules in a system (non-bond interactions and bonds).", "equation": "ΔU_L = ±mL", "notes": ["For melting and freezing, use the latent heat of fusion, L_f", "For boiling and condensing, use the latent heat of vaporization, L_v", "ΔU_L is positive for melting/vaporizing and negative for freezing/condensing."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"         | 8/35 [01:58<06:04, 13.52s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Arc Length", "definition": "The arc length is the distance traced out by a point rotating θ radians around a circle of radius r.", "equation": "s = rθ", "notes": ["θ must be in radians."]}, {"concept": "Angular Speed", "definition": "The angular speed of a rotating rigid object is related to the linear speed of a point on that body by its distance to the axis of rotation.", "equation": "ω = v / r", "notes": ["ω = dθ/dt", "The SI units of angular speed is radian/second (rad/sec)."]}, {"concept": "Moment of Inertia", "definition": "The moment of inertia of an object describes its rotational inertia – its ability to resist changes in rotation.", "equation": "I = ∫r²dm", "notes": ["The integral represents a sum of all tiny pieces of mass, dm, a distance, r, from the axis of rotation.", "The SI units for I is kg·m²."]}, {"concept": "Rotational Kinetic Energy", "definition": "The rotational kinetic energy of a rigid body depends on its moment of inertia and its angular speed.", "equation": "K_rot = 1/2 Iω²", "notes": ["This equation can only be used for particles or rigid bodies.", "This equation should only be used in the classical limit."]}, {"concept": "Rolling Without Slipping", "definition": "If an object is rolling without slipping, the linear speed of its center of mass is related to its angular speed by v_cm = ωr, where r is the radius of the object. An object that is rolling without slipping contains both linear and rotational kinetic energy.", "equation": "K_total = K_trans + K_rot = 1/2 mv_cm² + 1/2 Iω²", "notes": []}, {"concept": "Conservation of Energy in Rotation", "definition": "Solving conservation of energy problems including rotational energy, which involves kinetic energy, gravitational potential energy, elastic potential energy, thermal energy, and rotational energy in rotation.", "equation": "", "notes": []}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"         | 9/35 [02:08<05:23, 12.43s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Force", "definition": "A force describes a push or pull on an object. The force on an object is related to the spatial rate of change of the potential energy of the object.", "equation": "", "notes": []}, {"concept": "Force from Potential Energy", "definition": "This equation relates how an average component of force along the x-axis arises from a change in potential energy, which varies in space.", "equation": "F_x,ave = -ΔU/Δx", "notes": ["This equation can be used for any dimension, but it must be used for one-dimensional motion."]}, {"concept": "Equilibrium Position", "definition": "Regions on a potential energy graph where the force is zero. If the potential energy is at a minimum this is a stable equilibrium. If the potential energy is at a maximum it is an unstable equilibrium.", "equation": "", "notes": []}, {"concept": "Dot Product or Scalar Product", "definition": "A vector multiplication that relates components of two vectors which are parallel to each other.", "equation": ["a⃗ . b⃗ = a_x b_x + a_y b_y + a_z b_z", "a⃗ . b⃗ = |a⃗| |b⃗| cos θ"], "notes": ["The first version of the dot product is often used if you know the components of the vectors.", "The second version is often used if you know the magnitude of the vectors and the angle between them.", "Combining the first and second versions allows you to find the angle between two vectors."]}, {"concept": "Mechanical Work (constant force)", "definition": "This equation describes the work done by a constant force over a displacement.", "equation": "W = F⃗ ∙ d⃗", "notes": []}, {"concept": "Mechanical Work (non-constant force)", "definition": "This equation describes the work done by a force over a small displacement.", "equation": "W = ∫ F⃗ ⋅ dx⃗ from a to b", "notes": ["a and b represent initial and final positions of the displacement."]}, {"concept": "Work", "definition": "A measure of how much mechanical energy is transferred into or out of a system as a force acts over a displacement or distance.", "equation": "", "notes": ["Work is not energy itself, but is a measure of how much mechanical energy is transferred.", "Positive work on a system represents energy transferred into the system.", "Negative work on a system represents energy transferred out of a system.", "Positive work by a system represents energy transferred out of the system.", "Negative work by the system represents energy transferred into the system."]}, {"concept": "Work due to Conservative Force", "definition": "The work due to a conservative force is independent of the path taken. A conservative force is dependent only on the position of the object. Work due to a conservative force can be stored as potential energy.", "equation": "", "notes": []}, {"concept": "Work due to Non-conservative Force", "definition": "The work due to a non-conservative force depends on the path used in calculating the work. Often leads to mechanical energy loss that cannot be recovered.", "equation": "", "notes": ["Work due to friction is an example of work due to a non-conservative force."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 10/35 [02:23<05:31, 13.26s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Conservation of Energy (1st Law of Thermodynamics)", "definition": "This principle states that the change in energy of a system (∆E) is equal to the energy transferred into the system by heat (Q) and energy transferred into the system by work (W).", "equation": "∆E = Q + W", "notes": ["Both Q and W represent energy transfers into the system. If they transfer energy out, values are negative."]}, {"concept": "Mechanical Energy", "definition": "The sum of potential and kinetic energies in a system.", "equation": "", "notes": []}, {"concept": "Conservation of Mechanical Energy", "definition": "The change in mechanical energy of a system is equal to the mechanical work done on the system.", "equation": "∆Em = W", "notes": ["W represents energy transfer into the system. If mechanical energy transfers out, W is negative."]}, {"concept": "Work-Kinetic Energy Theorem", "definition": "The net work done on a particle (or non-deformable object) is equal to its total change in kinetic energy.", "equation": "Wnet = ∆K", "notes": ["Net work contains work due to both conservative and non-conservative forces."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 11/35 [02:29<04:28, 11.18s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Calorie and Kilocalorie", "definition": "Units for measuring heat. One calorie is equivalent to 4.184 joules, and one kilocalorie (Calorie) is equivalent to 4,184 joules.", "equation": "1 cal = 4.184 J, 1 kcal = 1 Cal = 4,184 J", "notes": ["Two commonly used units for heat."]}, {"concept": "Adenosine Triphosphate (ATP)", "definition": "A biomolecule that stores energy essential for the conversion of chemical energy to mechanical energy.", "equation": "", "notes": ["Energy storage of ATP is 29 kJ/kg.", "ATP is produced in the mitochondria of cells."]}, {"concept": "Energy Balance", "definition": "A measure of energy intake versus energy expenditure. Excess energy is stored as adipose tissue (fat).", "equation": "∆E_stored = E_food - E_exercise", "notes": ["Excess energy is stored as adipose tissue (fat)."]}, {"concept": "Basal Metabolic Rate (BMR) / Resting Energy Expenditure (REE)", "definition": "A measure of how much energy the body requires at minimum effort, estimated based on gender, height, weight, and age.", "equation": "", "notes": ["Can be estimated by the Harris-Benedict Formula or the Mifflin Formula."]}, {"concept": "One Pound of Adipose Tissue", "definition": "Stores 3,500 Calories (kcal) of energy.", "equation": "", "notes": []}, {"concept": "Nuclear Binding Energy", "definition": "Energy resulting from the mass deficit when protons and neutrons form a nucleus.", "equation": "∆E = ∆mc^2", "notes": ["The mass deficit is the difference between the mass of the constituent particles and the mass of the nucleus."]}, {"concept": "Binding Energy per Nucleon", "definition": "The binding energy of a nucleus divided by the total number of nucleons (protons and neutrons).", "equation": "∆e = ∆E / (n_p + n_n)", "notes": ["The binding energy per nucleon peaks at iron-56, indicating stability."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 12/35 [02:40<04:14, 11.05s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Power", "definition": "Power is the time rate of change of energy for a particle or a system.", "equation": "P = dE/dt", "notes": ["Power can be defined as the rate of change of any type of energy with respect to time be it potential, kinetic or internal energy.", "The SI unit of power is the Watt (W)."]}, {"concept": "Horsepower", "definition": "Horsepower is a non-standard, historical unit of power.", "equation": "1 hp = 745.7 W", "notes": []}, {"concept": "Kilowatt-hour", "definition": "The kilowatt-hour is a unit of energy often used to measure electricity usage in residential and commercial systems.", "equation": "1 kWh = 3.6 x 10^6 J = 3.6 MJ", "notes": []}, {"concept": "Power From Force and Velocity", "definition": "This equation relates how much energy per second (power) is transformed as a specific force, F, acts on an object moving with velocity, v.", "equation": "P = F⃗·v⃗", "notes": ["F⃗ must be constant over the time interval used for the equation to hold."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 13/35 [02:47<03:37,  9.87s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Center of Mass", "definition": "The center of mass of an extended object is the average position of its mass, calculated by summing the small portions of mass times their positions relative to the total mass.", "equation": "𝒓ሬ⃗𝒄𝒎= (1/𝑀) Σ𝒎𝒊𝒓ሬ⃗𝒊", "notes": ["For linear motion, an extended object can be treated as if all its mass is concentrated at its center of mass."]}, {"concept": "Momentum of a Particle", "definition": "The momentum of a particle is defined by its mass and velocity, considering the relativistic effects if necessary with the Lorentz factor.", "equation": "𝒑ሬሬ⃗= 𝜸𝒎𝒗ሬሬ⃗", "notes": ["In the classical limit, the momentum of a particle is 𝑝⃗= 𝑚𝑣⃗.", "The SI units of momentum are 𝑘𝑔∙𝑚/𝑠."]}, {"concept": "Impulse-Momentum Relationship", "definition": "The impulse-momentum relationship states that the impulse on an object is equal to its change in momentum.", "equation": "𝑱⃗= 𝚫𝒑ሬሬ⃗", "notes": ["Impulse is defined as the integral of force with respect to time or the average force multiplied by time: 𝐽⃗≡∫𝐹⃗𝑑𝑡≈ 𝐹⃗௔௩௘∆𝑡.", "In practice, the definition of impulse is used to relate to the change in momentum as 𝐹⃗௔௩௘∆𝑡= ∆𝑝⃗."]}, {"concept": "Force-Momentum Relationship", "definition": "The force-momentum relationship (Newton's 2nd law) tells us that the net force on an object is equal to the rate of change of momentum with respect to time.", "equation": "𝐅⃗𝐧𝐞𝐭= 𝒅𝒑ሬሬ⃗/𝒅𝒕", "notes": ["This equation can also be used to find the change in momentum caused by an individual force in the absence of other forces."]}, {"concept": "Conservation of Momentum", "definition": "The conservation of momentum states that the total momentum of an isolated system does not change.", "equation": "𝚫𝒑ሬሬ⃗𝒔𝒚𝒔= 𝟎", "notes": ["If the system is not isolated, the total change in momentum is related to the external force and the time over which it acts by the impulse-momentum relationship, ∆𝑝⃗௦௬௦= 𝐹⃗௘௫௧∆𝑡."]}]
# WARNING:root:Potential unrecognized equation format: 𝒓ሬ⃗𝒄𝒎= (1/𝑀) Σ𝒎𝒊𝒓ሬ⃗𝒊
# WARNING:root:Potential unrecognized equation format: 𝒑ሬሬ⃗= 𝜸𝒎𝒗ሬሬ⃗
# WARNING:root:Potential unrecognized equation format: 𝑱⃗= 𝚫𝒑ሬሬ⃗
# WARNING:root:Potential unrecognized equation format: \mathbf{F}𝐧𝐞𝐭= 𝒅𝒑ሬሬ⃗/𝒅𝒕
# WARNING:root:Potential unrecognized equation format: 𝚫𝒑ሬሬ⃗𝒔𝒚𝒔= 𝟎
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 14/35 [03:00<03:45, 10.73s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Elastic Collision", "definition": "An elastic collision is a type of collision where both energy and momentum are conserved.", "equation": "Δpsys = 0; ΔKsys = 0", "notes": ["Changes in potential energy can usually be ignored.", "We compare initial and final kinetic energies and momenta.", "The collision must occur on a fast scale to ensure conservation of momentum."]}, {"concept": "Inelastic Collision", "definition": "An inelastic collision is a type of collision where only momentum is conserved.", "equation": "Δpsys = 0", "notes": ["The collision must occur on a fast scale to ensure conservation of momentum.", "Involves only momentum conservation, allowing one unknown.", "In a perfectly inelastic collision, objects stick together, leading to one common final velocity."]}, {"concept": "Perfectly Inelastic Collision", "definition": "A special category of inelastic collisions where the objects stick together in the final state.", "equation": "p1,i + p2,i + ... = (m1 + m2 + m3 + ...) vf", "notes": ["The final velocity of all particles must be the same.", "The collision must occur on a fast scale to ensure conservation of momentum."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 15/35 [03:06<03:08,  9.42s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Conservation of Momentum", "definition": "The conservation of momentum for collisions involves utilizing the vector nature of momentum. The total momentum before the collision is equal to the total momentum after the collision.", "equation": "∆𝑝⃗= ቎ ∆𝑝௫ ∆𝑝௬ ∆𝑝௭ ቏= ൥ 0 0 0 ൩", "notes": []}, {"concept": "g-forces (g's)", "definition": "Human effects related to collisions and acceleration in general are measured using g-forces, denoted g's.", "equation": "𝑔ᇱ𝑠= 𝑎𝑐𝑐𝑒𝑙𝑒𝑟𝑎𝑡𝑖𝑜𝑛 𝑖𝑛 𝑐𝑜𝑙𝑙𝑖𝑠𝑖𝑜𝑛 / 9.8 𝑚/𝑠²", "notes": ["The effects depend on the strength and time of the collision, and the orientation of the body relative to the collision."]}, {"concept": "Rocket Equation", "definition": "This equation describes the change in speed of a rocket as a mass of fuel is ejected. It uses the conservation of momentum to increase the rocket's forward motion by offsetting the motion of fuel exhaust in the opposite direction.", "equation": "𝚫𝒗= 𝒗𝒆𝐥𝐧൬ 𝑴/ (𝑴 − 𝒎𝒆) ൰", "notes": ["This equation only works for non-relativistic speeds.", "M is the original mass of the rocket/fuel system.", "𝑚௘ is the mass of fuel ejected."]}]
# WARNING:root:Potential unrecognized equation format: 𝚫𝒗= 𝒗𝒆𝐥𝐧൬ 𝑴/ (𝑴 − 𝒎𝒆) ൰
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 16/35 [03:15<02:55,  9.22s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Vector Cross Product", "definition": "The cross-product of two vectors relates how perpendicular the vectors are. The magnitude of the cross product is the magnitude of one vector multiplied by the component of the other perpendicular to the first. The direction of the cross product is always perpendicular to both initial vectors and in a direction given by the right-hand rule.", "equation": "𝒂ሬሬ⃗ x 𝒃ሬሬ⃗ = (𝑎௬𝑏௭ − 𝑎௭𝑏௬, 𝑎௭𝑏௫ − 𝑎௫𝑏௭, 𝑎௫𝑏௬ − 𝑎௬𝑏௫)", "notes": ["In component form, the cross product is calculated using determinants of a matrix representation of the vectors."]}, {"concept": "Vector Cross Product (Magnitude/Angle form)", "definition": "The magnitude of the vector cross product of two vectors is given by the product of their magnitudes and the sine of the angle between them. The direction is determined using the right hand rule.", "equation": "|𝒂ሬሬ⃗ x 𝒃ሬሬ⃗| = |𝒂ሬ⃗||𝒃ሬ⃗|sin𝜃", "notes": ["Direction is given by the right hand rule."]}, {"concept": "Angular Momentum", "definition": "The angular momentum of a massive object around any reference point is given by the vector connecting the reference point and the object and the momentum of the object.", "equation": "𝑳ሬሬ⃗ = 𝒓ሬ⃗ x 𝒑ሬሬ⃗", "notes": ["The SI unit of angular momentum is 𝑘𝑔⋅𝑚²/𝑠."]}, {"concept": "Angular Momentum of a Rotating Rigid Body", "definition": "The angular momentum of a rotating rigid body is given by its moment of inertia and its angular velocity.", "equation": "𝑳ሬሬ⃗ = 𝑰𝝎ሬሬሬ⃗", "notes": ["The SI unit of angular momentum is 𝑘𝑔⋅𝑚²/𝑠."]}, {"concept": "Torque", "definition": "The torque on an object is the time rate of change of the angular momentum of the object.", "equation": "𝝉ሬ⃗𝒏𝒆𝒕 = 𝒅𝑳ሬሬ⃗/𝒅𝒕", "notes": ["The SI unit of torque is 𝑁⋅𝑚."]}]
# WARNING:root:Potential unrecognized equation format: 𝒂ሬሬ⃗ x 𝒃ሬሬ⃗ = (𝑎௬𝑏௭ − 𝑎௭𝑏௬ \\  𝑎௭𝑏௫ − 𝑎௫𝑏௭ \\  𝑎௫𝑏௬ − 𝑎௬𝑏௫)
# WARNING:root:Potential unrecognized equation format: |𝒂ሬሬ⃗ x 𝒃ሬሬ⃗| = |𝒂ሬ⃗||𝒃ሬ⃗|sin𝜃
# WARNING:root:Potential unrecognized equation format: 𝑳ሬሬ⃗ = 𝒓ሬ⃗ x 𝒑ሬሬ⃗
# WARNING:root:Potential unrecognized equation format: 𝑳ሬሬ⃗ = 𝑰𝝎ሬሬሬ⃗
# WARNING:root:Potential unrecognized equation format: 𝝉ሬ⃗𝒏𝒆𝒕 = 𝒅𝑳ሬሬ⃗/𝒅𝒕
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 17/35 [03:29<03:13, 10.73s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Angular Momentum", "definition": "Angular momentum is a vector quantity that represents the rotational analog of linear momentum. In an isolated system with no net external torque, the total angular momentum is conserved.", "equation": "dL_sys/dt = τ_net = 0 → L_sys = constant", "notes": ["An isolated system has no net external torque.", "Angular momentum is conserved in absence of external torques."]}, {"concept": "Conservation of Angular Momentum", "definition": "The conservation of angular momentum states that the total angular momentum of an isolated system remains constant.", "equation": "ΔL_sys = 0", "notes": ["The sum of changes in angular momentum for all objects in the system is zero: ΔL_sys = ΔL_1 + ΔL_2 + ΔL_3 + ..."]}, {"concept": "Gyroscope", "definition": "A gyroscope is a device that uses the conservation of angular momentum to provide stability and measure rotation. It typically includes a spin axis and two gimbal axes that are free to rotate relative to each other.", "equation": "", "notes": ["Used for ship stability and guidance, angle measurement, and precise position and orientation measurements."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 18/35 [03:35<02:37,  9.25s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Newton's First Law", "definition": "The velocity of an object does not change if it is not interacting with other objects.", "equation": "", "notes": ["An object in motion tends to stay in motion unless acted on by an outside force."]}, {"concept": "Newton's Second Law", "definition": "Relates the net force on an object to its change in momentum, and often its acceleration.", "equation": "F⃗ₙₑₜ = 𝑑𝑝⃗/𝑑𝑡", "notes": ["When the mass of an object moving at non-relativistic speeds is constant, 𝑑𝑝⃗/𝑑𝑡 reduces to 𝑚𝑎⃗."]}, {"concept": "Newton's Third Law", "definition": "The force on one of the interacting objects is equal in magnitude and opposite in direction to the force on the other interacting object.", "equation": "", "notes": ["For every action, there is an equal and opposite reaction."]}, {"concept": "Free-body Diagram", "definition": "A diagram used to visualize the force on individual objects by labeling each diagram with all of the forces that act on the body.", "equation": "", "notes": ["Newton’s laws and free-body diagrams are done with respect to individual objects."]}, {"concept": "Gravitational Force", "definition": "The gravitational force on an object is given by the mass of the object multiplied by the local gravitational field strength.", "equation": "𝐹⃗₉ = 𝑚𝑔⃗", "notes": ["Near the surface of the earth, the gravitational field strength is often given as 9.80 𝑚/𝑠² or 9.80 𝑁/𝑘𝑔."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 19/35 [03:44<02:23,  8.97s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Kinematic Relationships", "definition": "Kinematic relationships describe the mathematical relationships between position, velocity, and acceleration for motion. These relationships vary depending on whether the initial known parameter is position, velocity, or acceleration.", "equation": "", "notes": []}, {"concept": "Kinematic Relationships (starting with position)", "definition": "These are equations used to determine velocity and acceleration from a known position as a function of time.", "equation": ["v⃗(t) = d/dt x⃗(t)", "a⃗(t) = d/dt v⃗(t) = d²/dt² x⃗(t)"], "notes": ["These equations show the relationships for a system where position is initially known as a function of time."]}, {"concept": "Kinematic Relationships (starting with acceleration)", "definition": "These equations allow calculation of velocity and position from a given acceleration as a function of time.", "equation": ["v⃗(t) − v⃗₀ = ∫₀ᵗ a⃗(τ) dτ", "x⃗(t) − x⃗₀ = ∫₀ᵗ v⃗(τ) dτ"], "notes": ["These equations show the relationships for a system where acceleration is initially known as a function of time."]}, {"concept": "Kinematic Relationships (starting with velocity)", "definition": "These are equations used to determine position and acceleration from a known velocity as a function of time.", "equation": ["x⃗(t) − x⃗₀ = ∫₀ᵗ v⃗(τ) dτ", "a⃗(t) = d/dt v⃗(t)"], "notes": ["These equations show the relationships for a system where velocity is initially known as a function of time."]}, {"concept": "Constant Acceleration Kinematics Equations (1-D)", "definition": "Special set of kinematic equations used when acceleration is constant, directly relating position, velocity, and time.", "equation": ["a = a", "v(t) = v₀ + a·t", "x(t) = x₀ + v₀·t + 1/2·a·t²", "v²(t) = v₀² + 2·a[x(t) − x₀]"], "notes": ["Applicable only when there is constant acceleration.", "x₀ and v₀ represent the initial position and velocity, respectively."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 20/35 [03:57<02:32, 10.18s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Position-versus-time graph", "definition": "A graph that shows how the position of an object changes over time.", "equation": "", "notes": ["Used to describe motion graphically", "Sections indicate discontinuities, changes in slope, or changes in concavity."]}, {"concept": "Velocity-versus-time graph", "definition": "A graph that shows how the velocity of an object changes over time.", "equation": "", "notes": ["Each section represents the slope of the corresponding section in a position-versus-time graph."]}, {"concept": "Acceleration-versus-time graph", "definition": "A graph that depicts how the acceleration of an object changes over time.", "equation": "", "notes": ["Each section represents the slope of the corresponding section in a velocity-versus-time graph."]}, {"concept": "Direction of derivatives", "definition": "The process of determining graphs by taking the derivatives of other related graphs.", "equation": "", "notes": ["Velocity graph sections are the slope of position graph sections.", "Acceleration graph sections are the slope of velocity graph sections."]}, {"concept": "Direction of antiderivatives", "definition": "The process of determining graphs by taking the antiderivatives of other related graphs.", "equation": "", "notes": ["Velocity graph points represent the area under the curve of the acceleration graph.", "Position graph points represent the area under the curve of the velocity graph."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 21/35 [04:03<02:06,  9.00s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Ideal Projectile Motion", "definition": "Objects tossed through the air at relatively low velocity can be modeled as if they are only acted on by gravity.", "equation": "", "notes": ["This is an approximation where only gravity is considered as the force acting on the projectile."]}, {"concept": "Acceleration (Projectile Motion)", "definition": "This equation gives the vector acceleration of an object in the ideal projectile motion approximation.", "equation": "a(t) = [0, 0, -g]", "notes": ["g is the local gravitational field strength in which the projectile moves."]}, {"concept": "Velocity (Projectile Motion)", "definition": "This equation gives the velocity as a function of time for an object moving in ideal projectile motion with initial velocity.", "equation": "v(t) = [v0,x, v0,y - gt, v0,z]", "notes": ["g is the local gravitational field strength in which the projectile moves.", "The initial velocity is given by v0 = [v0,x, v0,y, v0,z]."]}, {"concept": "Position (Projectile Motion)", "definition": "This equation gives the position as a function of time for an object moving in ideal projectile motion with initial velocity and position.", "equation": "r(t) = [v0,xt + x0, v0,yt + y0, -1/2 gt^2 + v0,zt + z0]", "notes": ["g is the local gravitational field strength in which the projectile moves.", "Initial position is given by r0 = [x0, y0, z0]."]}, {"concept": "Pathlength of a Projectile", "definition": "The path length of a projectile can be found by integrating the magnitude of the velocity (speed) over the time of interest.", "equation": "", "notes": ["The equation for path length becomes quite complicated."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 22/35 [04:13<02:00,  9.25s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Types of Forces", "definition": "The forces that can act on an object are directly related to the interactions the object undergoes.", "equation": "", "notes": []}, {"concept": "Free-Body Diagram", "definition": "A visual representation of multiple forces exerted on an object.", "equation": "", "notes": []}, {"concept": "Net Force", "definition": "The vector sum of all the forces acting on an object.", "equation": "F⃗net = F⃗1 + F⃗2 + F⃗3 + …", "notes": ["Each individual force in this equation should come from one force in a free body diagram."]}, {"concept": "Newton’s Second Law", "definition": "The equation relates the net force on an object to the acceleration that the object undergoes.", "equation": "F⃗net = ma⃗", "notes": ["Newton’s second law equations must be done for each object in a system separately."]}, {"concept": "Torque Due to an Individual Force", "definition": "The torque on an object due to a single force is given by the cross product of the displacement of the force from the axis of rotation and the force itself.", "equation": "τ⃗ = r⃗ x F⃗", "notes": []}, {"concept": "Newton’s 2nd Law for Rotation", "definition": "Newton’s 2nd law for rotation relates the net torque on an object to the moment of inertia and angular acceleration of the object.", "equation": "τ⃗net = Iα⃗", "notes": ["The 2nd law for rotation must be used for each object in a system individually."]}, {"concept": "Force and Torque in Classical Limit", "definition": "In the classical limit, when mass (F⃗) and moment of inertia (τ⃗) are constant, force and torque are related to rate of change of momentum and angular momentum, respectively.", "equation": "F⃗ = dp⃗/dt → F⃗ = ma⃗, τ⃗ = dL⃗/dt → τ⃗ = Iα⃗", "notes": []}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 23/35 [04:26<02:04, 10.36s/section]
# ...
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 27/35 [05:06<01:16,  9.56s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Circular Motion", "definition": "Motion in a circular path which can be either uniform (constant speed) or non-uniform (varying speed).", "equation": "", "notes": []}, {"concept": "Centripetal Acceleration", "definition": "The acceleration that keeps an object moving in a circular path, related to the speed of the object and the radius of the circle.", "equation": "𝑎⃗𝑐 = −𝑣²/𝑟 𝑟̂", "notes": ["The radial vector, 𝑟̂, always points away from the center of circulation; therefore, −𝑟̂ always points towards the center of circulation."]}, {"concept": "Acceleration in Non-uniform Circular Motion", "definition": "Describes how circular motion with varying speeds involves both centripetal acceleration and tangential acceleration.", "equation": "𝑎⃗𝑡𝑜𝑡𝑎𝑙 = −𝑣²/𝑟 𝑟̂ + 𝑑𝑣/𝑑𝑡 𝜃̂", "notes": ["The equation uses a coordinate system defined relative to the instantaneous direction of motion with 𝜃̂ in the direction of motion and 𝑟̂ perpendicular to the motion."]}, {"concept": "Newton’s Universal Law of Gravity", "definition": "Describes the gravitational force between two massive objects.", "equation": "𝐹⃗𝑔 = −𝐺𝑚₁𝑚₂/𝑟² 𝑟̂", "notes": ["For a circular orbit, |𝐹⃗𝑔| = 𝑚𝑎𝑐 = 𝑚𝑣²/𝑟"]}, {"concept": "Period (Circular Motion)", "definition": "The time it takes an object moving in uniform circular motion to traverse completely around the circle.", "equation": "𝑇 = 2π𝑟/𝑣", "notes": ["This equation is defined only for uniform circular motion."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 28/35 [05:16<01:07,  9.63s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Hooke's Law", "definition": "Relates the displacement of a spring from equilibrium to the restoring force of the spring.", "equation": "F⃗ = −k(x⃗ −x⃗₀)", "notes": ["The equation describes the force of an object on a spring with stiffness, k, and displacement from equilibrium, (x⃗ −x⃗₀)."]}, {"concept": "Block-Spring Oscillation", "definition": "Describes the position as a function of time of a linear oscillator with amplitude, A, angular frequency, ω₀, and initial phase, φ, at time t.", "equation": "x(t) = A cos(ω₀t−φ)", "notes": ["For an object with mass m on a spring with stiffness k, the angular frequency is given by ω₀ = √(k/m)."]}, {"concept": "Pendulum (Small Angles)", "definition": "Describes the angular position as a function of time of a pendulum with amplitude, θ₀, angular frequency, ω₀, and initial phase, φ, at time t.", "equation": "θ(t) = θ₀ cos(ω₀t−φ)", "notes": ["For a pendulum with length l in gravitational field strength g, ω₀ = √(g/l).", "This equation only holds for small oscillations."]}, {"concept": "Damping Ratio", "definition": "Describes the damping ratio, χ, of a damped mass-spring oscillator in terms of the damping coefficient, b, the mass of the oscillator, m, and the spring constant, k.", "equation": "χ = b/(2√(mk))", "notes": ["Overdamped: χ > 1; critically damped: χ = 1; underdamped: χ < 1.", "ωᵈ = ω₀√(1 − χ²)."]}, {"concept": "Forced-Damped Motion", "definition": "Occurs when a sinusoidal forcing function acts on a damped oscillator, exhibiting resonance when the driving frequency matches the natural frequency.", "equation": "x(t) = A_f cos(ω_f t−φ)", "notes": ["ω_f is the angular frequency of the driving force.", "A_f = (F₀/m) / √((ω₀²−ω_f²)² + (b/m)² ω_f²)."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 29/35 [05:28<01:01, 10.33s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Stress", "definition": "A measure of force per unit area placed on a solid object.", "equation": "", "notes": []}, {"concept": "Strain", "definition": "The ratio of deformation to initial length, ∆L/L₀.", "equation": "", "notes": ["While under stress"]}, {"concept": "Hooke's Law (Tension/Compression)", "definition": "Relates the magnitude of a force placed on an object to the change in length of the object.", "equation": "||F⃗_T|| = keΔL", "notes": ["ke is the effective spring constant"]}, {"concept": "Young's Modulus", "definition": "The ratio of tensile strength to tensile strain along one axis for a given material.", "equation": "", "notes": ["Tensile stresses change the length of an object along one axis"]}, {"concept": "Tensile and Compression Deformation", "definition": "Relates the change in length along one axis of an object, ∆L, to the object's unstressed length, L₀, the force on the object, F, and the cross-sectional area of the object, A and the Young's modulus of the material, Y.", "equation": "ΔL = (1/Y) (F/A) L₀", "notes": ["The effective spring constant for tensile stress is ke= YA/L₀"]}, {"concept": "Shear Modulus", "definition": "The ratio of shear stress to shear strain.", "equation": "", "notes": ["Shear stresses change the shape of the material by bending them"]}, {"concept": "Shear Deformation", "definition": "Relates the initial length of an object, L₀, to the change in position of one end of the object relative to the other, ∆x, perpendicular to the length, while under a shear force, F.", "equation": "Δx = (1/G) (F/A) L₀", "notes": ["A is the cross-sectional area of the object parallel to the force", "G is the shear modulus of the material"]}, {"concept": "Bulk Modulus", "definition": "Measures a substance's resistance to uniform compression. It is the ratio of volume stress to volume strain (change in volume).", "equation": "", "notes": []}, {"concept": "Bulk (Volume) Deformation", "definition": "Relates the change in volume, ∆V, to the initial volume of an object, V₀, while under a force per unit area, F/A, acting on the object from all sides.", "equation": "ΔV = (1/K) (F/A) V₀", "notes": ["K is the bulk modulus of the material"]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 30/35 [05:42<00:58, 11.68s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Common States of Matter", "definition": "The three most common states of matter are solids, liquids, and gases.", "equation": "", "notes": ["Solid: Molecules are locked into place, making the material rigid, although it can be deformed by external forces.", "Liquid: Molecules are free to move relative to each other, but intermolecular forces keep them close. Liquids flow, but their density remains relatively constant under pressure.", "Gas: Molecules are free to move and interact weakly, allowing gases to flow and change density due to external pressure."]}, {"concept": "Pressure", "definition": "Pressure is a measure of how much force is distributed over an area.", "equation": "P = |dF⃗N| / dA", "notes": ["The standard unit of pressure is the Pascal, where 1 Pa = 1 N/m².", "A commonly used unit for pressure is the atmosphere (atm), where 1 atm = 101.3 kPa."]}, {"concept": "Variation of Pressure with Depth", "definition": "Pressure varies with depth due to gravity.", "equation": "P = P0 + ρgh", "notes": ["P is the pressure at depth h below a point where the pressure is known to be P0.", "ρ is the density of the fluid.", "g is the gravitational field strength."]}, {"concept": "Force of Buoyancy", "definition": "The force of buoyancy is derived from the variation of pressure with depth.", "equation": "FB = ρfluid g Vdisplaced", "notes": ["FB is the buoyant force for an object submerged displacing a volume Vdisplaced of fluid with density ρfluid.", "g is the gravitational field strength.", "The force of buoyancy is directed towards lower pressure, usually, but not always, upwards."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"        | 31/35 [05:53<00:45, 11.32s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Ideal Fluid", "definition": "A fluid that is incompressible, exhibits steady, non-rotational flow, and ignores viscosity.", "equation": "", "notes": ["An ideal fluid cannot include gases because it must be incompressible."]}, {"concept": "Continuity Equation", "definition": "The volume flow rate, Q, of an ideal fluid is equal to the velocity of the fluid multiplied by the cross-sectional area of the flow. The continuity equation states that the volume flow rate of an ideal fluid is constant.", "equation": "Q = vA = constant ⇒ v1A1 = v2A2", "notes": ["This equation only holds for incompressible fluids.", "The units for volume flow rate is m³/s."]}, {"concept": "Bernoulli’s Equation", "definition": "Bernoulli’s equation states that the sum of the pressure in a fluid, kinetic energy density, and gravitational potential energy density in a fluid is constant for the entire fluid flow.", "equation": "P1 + 1/2 ρv1² + ρgz1 = P2 + 1/2 ρv2² + ρgz2", "notes": ["This only holds for ideal fluids."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"█▊      | 32/35 [06:01<00:30, 10.26s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Viscosity", "definition": "Viscosity is a measure of friction in a fluid.", "equation": "η = Fy / v₀A", "notes": ["This equation defines the viscosity of a fluid as found by placing the fluid between two flat plates.", "F is the force it takes to keep the upper plate a fixed distance, y, above a stationary plate of cross-sectional area, A, moving at a speed, v₀, relative to the stationary plate.", "The unit of viscosity is Pa⋅s."]}, {"concept": "Poiseuille’s Law", "definition": "Poiseuille’s Law tells us how a difference in pressure between two points (1 and 2) is related to the volume flow rate of a fluid, the fluid viscosity, and the length and radius of the tube the fluid flows in.", "equation": "P₁−P₂ = 8ηLQ / πr⁴", "notes": ["It describes how pressure decreases in a real fluid as it flows and how a difference in pressure can cause a fluid flow."]}, {"concept": "Reynolds’s Number for Tube Flow", "definition": "Reynolds’s Number helps us determine whether a flow is laminar or turbulent for fluid flow in a tube.", "equation": "Rₑ = 2ρvr / η", "notes": ["This equation defines the Reynold’s Number for fluid flow in a tube of radius r in terms of the density of the fluid, ρ, the speed of the fluid flow, v, and the viscosity of the fluid, η.", "Flow is laminar if Rₑ < 2000, unstable if Rₑ is between 2000 and 3000, and turbulent if Rₑ > 3000."]}, {"concept": "Reynolds’s Number for Object Moving in a Fluid", "definition": "Reynolds’s Number helps us determine whether flow behind an object is laminar, unstable, or exhibits a turbulent wake in a fluid.", "equation": "R'ₑ = ρvL / η", "notes": ["This equation defines the Reynold’s Number for an object in a fluid in terms of the density of the fluid, ρ, the speed of the object, v, a characteristic length of the object, L, and the viscosity of the fluid, η.", "Flow behind the object is laminar if R'ₑ < 1, unstable if R'ₑ is between 1 and 10⁶, and exhibits a turbulent wake if R'ₑ > 10⁶.", "You must be very careful with the variable definitions as they are not as standard for real fluids as in other areas of introductory physics.", "Each equation box explicitly defines the variables used."]}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"███▉    | 33/35 [06:20<00:26, 13.07s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Derivative of a Function", "definition": "The derivative of a function of a single variable represents the rate of change of the function at a given point. On a graph, the derivative of a function is the slope of the function at a given point. The mathematical definition of the derivative gives us a way to find the desired rate of change of any function.", "equation": "f'(t) = df(t)/dt = lim (h→0) [f(t+h) - f(t)]/h", "notes": ["In practice, using the definition can be very hard.", "Two common notations for a derivative are f'(t) and df(t)/dt.", "The definition is often given as a derivative with respect to time, but could be with respect to other variables such as x."]}, {"concept": "Basic Derivatives", "definition": "Derivative formulas for common basic functions.", "equation": "d/dt(n) = 0, d/dt(t^n) = nt^(n-1), d/dt(sin nt) = n cos nt, d/dt(cos nt) = -n sin nt, d/dt(e^(nt)) = n e^(nt)", "notes": ["n represents any constant value and t is the variable for these examples."]}, {"concept": "Constant Multiple Rule", "definition": "When a constant multiplies a function, the constant can be factored out of the derivative.", "equation": "d/dt(nf(t)) = n df(t)/dt", "notes": []}, {"concept": "Sum Rule in Derivatives", "definition": "The sum rule tells us that if we have the sum of two functions, the derivative of the sum is the sum of the derivatives of the individual functions.", "equation": "d[f(t) + g(t)]/dt = f'(t) + g'(t)", "notes": ["This rule is for two functions of a single variable f(t) and g(t), which are added together."]}, {"concept": "Product Rule in Derivatives", "definition": "The product rule gives us a way of finding the derivative of two functions of a single variable multiplied together.", "equation": "d[f(t)g(t)]/dt = f'(t)g(t) + f(t)g'(t)", "notes": ["This rule is for two functions of a single variable f(t) and g(t), which are multiplied together."]}, {"concept": "Higher Order Derivatives", "definition": "Higher order derivatives are obtained by taking consecutive derivatives of a function.", "equation": "First derivative: x'(t) = dx/dt, Second derivative: x''(t) = d/dt [x'(t)], Third derivative: x'''(t) = d/dt [x''(t)], etc.", "notes": []}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"█████▉  | 34/35 [06:41<00:15, 15.31s/section]
# INFO:root:Raw OpenAI response: [{"concept": "Antiderivative", "definition": "The antiderivative of a function 𝑓(𝑡) is a function 𝑔(𝑡) such that its derivative is 𝑓(𝑡).", "equation": "∫𝑓(𝑡)𝑑𝑡 = 𝑔(𝑡)", "notes": ["The antiderivative is only defined up to a constant.", "Indefinite integrals must include a constant term, e.g., ∫𝑡²𝑑𝑡 = 𝑡³/3 + 𝐶."]}, {"concept": "Definite Integral", "definition": "The definite integral of a function is the antiderivative of that function evaluated over a specific region.", "equation": "", "notes": ["Graphically represents the area under the curve of the function between two points."]}, {"concept": "Fundamental Theorem of Calculus", "definition": "The theorem states that the integral of a derivative function 𝑓’(𝑡) over an interval is equal to the difference of the values of the original function 𝑓(𝑡) at the endpoints.", "equation": "∫[a to b] 𝑓'(𝑡)𝑑𝑡 = 𝑓(𝑏) − 𝑓(𝑎)", "notes": ["The antiderivative of the integrand must be known to compute the integral from this theorem."]}, {"concept": "Important Antiderivatives", "definition": "Common antiderivatives to know for basic functions with respect to 𝑡.", "equation": "", "notes": ["∫𝑎𝑑𝑡 = 𝑎𝑡 + 𝐶", "∫𝑡ⁿ𝑑𝑡 = 𝑡ⁿ⁺¹/(𝑛+1) + 𝐶", "∫sin(𝑎𝑡)𝑑𝑡 = −1/𝑎 cos(𝑎𝑡) + 𝐶", "∫cos(𝑎𝑡)𝑑𝑡 = 1/𝑎 sin(𝑎𝑡) + 𝐶", "∫𝑒ᵃᵗ𝑑𝑡 = 1/𝑎 𝑒ᵃᵗ + 𝐶"]}]
# Extracting Concepts: 100%|████████████████████████████████████████████████████████████████████████| 35/35 [06:58<00:00, 11.96s/section]
# Extracted concepts saved to data/json/bare_essentials_concepts.json

# %%
with open("data/json/bare_essentials_concepts.json", "r") as f:
    data = json.load(f)

print(json.dumps(data, indent=4))
# Out:
# [
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "Physics",
#         "definition": "The study of matter, energy, and their interactions.",
#         "equation": "$$",
#         "notes": []
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "Four Fundamental Interactions",
#         "definition": "Interactions that describe the universe with different relative strengths.",
#         "equation": "$$",
#         "notes": [
#             "Strong Nuclear Interaction: Short-range interaction between quarks and gluons responsible for keeping quarks together in nucleons, and nucleons together in nuclei.",
#             "Weak Nuclear Interaction: Short-range interaction responsible for nuclear radioactivity.",
#             "Gravitational Interaction: Long-range, attractive interaction between massive particles.",
#             "Electromagnetic Interaction: Long-range interaction between electrically charged particles."
#         ]
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "Standard Model",
#         "definition": "The most widely accepted fundamental model for our universe.",
#         "equation": "$$",
#         "notes": [
#             "Composed of three basic types of particles: Fermions and Bosons.",
#             "Fermions: Subatomic particles with half-integer spin.",
#             "Quarks: Experience all fundamental interactions and combine to form massive particles such as protons and neutrons.",
#             "Leptons: Do not experience the strong interaction. Often products of nuclear reactions mediated by the weak interaction.",
#             "Bosons: Subatomic particles with integer spin. Carry information about interactions between particles.",
#             "Each fundamental interaction has at least one boson: Photons (electromagnetic), Gluons (strong nuclear), W and Z bosons (weak nuclear), Graviton (gravity - theoretical).",
#             "Problems with the standard model lead to extensions including string theory and attempts to explain dark matter and dark energy."
#         ]
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "Significant Figures",
#         "definition": "Used to determine the precision with which a measurement or calculation is made.",
#         "equation": "$$",
#         "notes": [
#             "Generally, two or three significant figures are used in Physics I and II."
#         ]
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "Fundamental Quantities in Physics",
#         "definition": "Basic units of measurement in physics.",
#         "equation": "$$",
#         "notes": [
#             "Energy (J or eV)",
#             "Mass (kg, amu or eV/c2)",
#             "Length (m)",
#             "Time (s)"
#         ]
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "SI Prefixes",
#         "definition": "Used to describe the scale of quantities in physics.",
#         "equation": "$$",
#         "notes": []
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "Nuclear Symbol",
#         "definition": "The nuclear symbol for an atom with chemical symbol X is described by its number of protons (Z), the total number of nucleons (A).",
#         "equation": "$$",
#         "notes": [
#             "The chemical symbol (X) and the number of protons are redundant; however, in physics, both are often expressed for ease of use.",
#             "The number of neutrons in a nucleus is given by the neutron number, N = A \u2013 Z."
#         ]
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "Nuclear Radius",
#         "definition": "This equation describes the radius of a nucleus, r, with nuclear number, A.",
#         "equation": "$r = r0A^{\\frac{1}{3}}$",
#         "notes": [
#             "r0 = 1.25 fm."
#         ]
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "Neutral Atom",
#         "definition": "An electrically neutral atom has the same number of electrons as protons with the electrons in shells around the nucleus of the atom.",
#         "equation": "$$",
#         "notes": []
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "Ion",
#         "definition": "An ion is an atom or molecule where the number of electrons does not match the number of protons.",
#         "equation": "$$",
#         "notes": []
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "Macroscopic Interactions",
#         "definition": "Macroscopic interactions describe the results of the fundamental interactions that we see in everyday life. Except for the macroscopic gravitational interaction, all macroscopic interactions are a result of the fundamental electromagnetic interaction.",
#         "equation": "$$",
#         "notes": []
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "System",
#         "definition": "A system is a part of the universe being studied.",
#         "equation": "$$",
#         "notes": [
#             "An isolated system is a system of objects that we can consider to undergo no interactions with objects outside of the system.",
#             "The environment is the area outside of the system which is ignored except for specific interactions with the system."
#         ]
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "Model",
#         "definition": "In physics, a model is a set of rules and assumptions used to define a problem.",
#         "equation": "$$",
#         "notes": [
#             "Two important models used in this course are classical mechanics and special relativity."
#         ]
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "Interactions",
#         "definition": "Interactions come in three forms: fundamental interactions, mechanical interactions, and microscopic interactions.",
#         "equation": "$$",
#         "notes": [
#             "Fundamental interactions: The four fundamental interactions.",
#             "Mechanical interactions: Interactions that lead to a change in motion.",
#             "Microscopic interactions: Interactions that lead to a non-mechanical, macroscopic change (change in temperature, phase, shape, etc.)."
#         ]
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "Scalar",
#         "definition": "Scalars are quantities that only require a number to describe them fully.",
#         "equation": "$$",
#         "notes": []
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "Vector",
#         "definition": "Vectors are quantities that require both a magnitude and direction to be fully described.",
#         "equation": "$$",
#         "notes": [
#             "A vector can be described in terms of its components relative to a set of axes."
#         ]
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "Vector Notation",
#         "definition": "Defines the vector notation for a vector with components along x-, y-, and z-axes, respectively.",
#         "equation": "$\ud835\udc4e\u20d7= \\begin{bmatrix} \ud835\udc4ex \\\\  \ud835\udc4ey \\\\  \ud835\udc4ez \\end{bmatrix} = \ud835\udc4ex\ud835\udea4\u0302 + \ud835\udc4ey\ud835\udea5\u0302 + \ud835\udc4ez\ud835\udc58\u0de0$",
#         "notes": [
#             "The choice of \ud835\udea4\u0302, \ud835\udea5\u0302, and \ud835\udc58\u0de0 for the unit-vector notation is arbitrary; however, these most often correspond to the x-, y-, and z-axes, respectively."
#         ]
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "Vector Components",
#         "definition": "Defines the components of a vector based on trigonometric relationships to its magnitude and angle.",
#         "equation": "$\ud835\udc4ex = |\ud835\udc4e\u20d7| cos \ud835\udf03x\u2192y \\\\  \ud835\udc4ey = |\ud835\udc4e\u20d7| sin \ud835\udf03x\u2192y$",
#         "notes": [
#             "|\ud835\udc4e\u20d7| is the magnitude of vector \ud835\udc4e\u20d7.",
#             "These equations are extensible to any plane. For example, in the y-z plane with angle measured off of y-axis, \ud835\udc4ey= |\ud835\udc4e\u20d7| cos \ud835\udf03y\u2192z, \ud835\udc4ez= |\ud835\udc4e\u20d7| sin \ud835\udf03y\u2192z."
#         ]
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "Magnitude/Angle Notation",
#         "definition": "Describes a vector in terms of its magnitude and direction relative to a given axis.",
#         "equation": "$|\ud835\udc4e\u20d7| = \u221a(\ud835\udc4ex\u00b2 + \ud835\udc4ey\u00b2) \\\\  \ud835\udf03x\u2192y = atan(\ud835\udc4ey/\ud835\udc4ex)$",
#         "notes": [
#             "The angle, \ud835\udf03x\u2192y, is measured from the positive x-axis towards the positive y-axis.",
#             "These equations are extensible to any plane. For example, the angle of a vector in the y-z plane, measured from the y-axis towards the z-axis is \ud835\udf03y\u2192z = atan(\ud835\udc4ez/\ud835\udc4ey)."
#         ]
#     },
#     {
#         "unit": null,
#         "section": "Bare Essentials",
#         "concept": "Three-Dimensional Vector Description",
#         "definition": "Defines a three-dimensional vector using components and angles similar to two-dimensional vectors.",
#         "equation": "$\ud835\udc4e\u20d7 = \\begin{bmatrix} \ud835\udc4ex \\\\  \ud835\udc4ey \\\\  \ud835\udc4ez \\end{bmatrix} = \ud835\udc4ex\ud835\udea4\u0302 + \ud835\udc4ey\ud835\udea5\u0302 + \ud835\udc4ez\ud835\udc58\u0de0 \\\\  |\ud835\udc4e\u20d7| = \u221a(\ud835\udc4ex\u00b2 + \ud835\udc4ey\u00b2 + \ud835\udc4ez\u00b2) \\\\  \ud835\udf03x\u2192y = atan(\ud835\udc4ey/\ud835\udc4ex) \\\\  \ud835\udf03xy\u2192z = atan(\ud835\udc4ez/\u221a(\ud835\udc4ex\u00b2 + \ud835\udc4ey\u00b2))$",
#         "notes": [
#             "\ud835\udf03xy\u2192z is the angle of inclination, an angle measured from the xy-plane towards the z-axis.",
#             "Components: \ud835\udc4ex= |\ud835\udc4e\u20d7| cos \ud835\udf03x\u2192y cos \ud835\udf03xy\u2192z, \ud835\udc4ey= |\ud835\udc4e\u20d7| sin \ud835\udf03x\u2192y cos \ud835\udf03xy\u2192z, \ud835\udc4ez= |\ud835\udc4e\u20d7| sin \ud835\udf03xy\u2192z."
#         ]
#     },
#     {
#         "unit": "Unit 104 gives an overview of the two major principles developed in this book as well as a glimpse at the \u2018Laws\u2019 that",
#         "section": "Bare Essentials",
#         "concept": "Energy",
#         "definition": "A fundamental quantity that particles can possess. The energy of a particle can be made up of rest-mass energy, kinetic energy, and potential energy. The total energy of a particle is the sum of each of these energies.",
#         "equation": "$Not provided explicitly in the text.$",
#         "notes": [
#             "Rest-mass, kinetic, and total energy equations are mentioned but not provided."
#         ]
#     },
#     {
#         "unit": "Unit 104 gives an overview of the two major principles developed in this book as well as a glimpse at the \u2018Laws\u2019 that",
#         "section": "Bare Essentials",
#         "concept": "Conservation of Energy (Isolated System)",
#         "definition": "The total energy contained in an isolated system does not change.",
#         "equation": "$\ud835\udeab\ud835\udc6c= \ud835\udfce$",
#         "notes": [
#             "An isolated system is defined as a system that does not interact with its surroundings."
#         ]
#     },
#     {
#         "unit": "Unit 104 gives an overview of the two major principles developed in this book as well as a glimpse at the \u2018Laws\u2019 that",
#         "section": "Bare Essentials",
#         "concept": "Energy Transfer Forms",
#         "definition": "Energy can be transferred into or out of a system in various forms such as heat, thermodynamic work, and mechanical work.",
#         "equation": "$$",
#         "notes": [
#             "Heat is due to temperature differences.",
#             "Thermodynamic work is due to mechanical and microscopic interactions, not temperature differences.",
#             "Mechanical work is a subset of thermodynamic work, related to mechanical interactions."
#         ]
#     },
#     {
#         "unit": "Unit 104 gives an overview of the two major principles developed in this book as well as a glimpse at the \u2018Laws\u2019 that",
#         "section": "Bare Essentials",
#         "concept": "Momentum",
#         "definition": "The momentum of an individual particle is given by the product of its mass, velocity, and the Lorentz factor.",
#         "equation": "$\ud835\udc5d\u20d7= \ud835\udefe\ud835\udc5a\ud835\udc63\u20d7$",
#         "notes": []
#     },
#     {
#         "unit": "Unit 104 gives an overview of the two major principles developed in this book as well as a glimpse at the \u2018Laws\u2019 that",
#         "section": "Bare Essentials",
#         "concept": "Conservation of Momentum (Isolated System)",
#         "definition": "The total momentum contained in an isolated system does not change.",
#         "equation": "$\ud835\udeab\ud835\udc91\u122c\u122c\u20d7= \ud835\udfce$",
#         "notes": [
#             "An isolated system is defined as a system that does not interact with its surroundings."
#         ]
#     },
#     {
#         "unit": "Unit 104 gives an overview of the two major principles developed in this book as well as a glimpse at the \u2018Laws\u2019 that",
#         "section": "Bare Essentials",
#         "concept": "Newton\u2019s Laws",
#         "definition": "A set of three fundamental laws that describe motion and interactions of particles.",
#         "equation": "$$",
#         "notes": [
#             "Newton\u2019s 1st Law: The velocity of a particle does not change when it is not undergoing any interactions.",
#             "Newton\u2019s 2nd Law: The net force on an object is equal to the rate of change of its momentum.",
#             "Newton\u2019s 3rd Law: Forces between two interacting objects are equal in magnitude and opposite in direction.",
#             "Newton\u2019s Laws apply to individual particles, unlike conservation laws which deal with entire systems."
#         ]
#     },
#     {
#         "unit": "Unit 104 gives an overview of the two major principles developed in this book as well as a glimpse at the \u2018Laws\u2019 that",
#         "section": "Bare Essentials",
#         "concept": "Newton\u2019s Second Law",
#         "definition": "The equation relates the net force on an object to the rate of change of the object's momentum.",
#         "equation": "$\\mathbf{F}\ud835\udc27\ud835\udc1e\ud835\udc2d= \ud835\udc85\ud835\udc91\u122c\u122c\u20d7 \ud835\udc85\ud835\udc95$",
#         "notes": [
#             "When the mass of an object moving at non-relativistic speeds is constant, the equation reduces to \ud835\udc5a\ud835\udc4e\u20d7."
#         ]
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Position Vector",
#         "definition": "The position of an object is its vector relationship to a reference point (usually the origin of a coordinate system).",
#         "equation": "$\ud835\udc93\ud835\udc93\u122c\u20d7 = \\begin{bmatrix} \ud835\udc93\ud835\udc93\ud835\udc99\ud835\udc99 \\\\  \ud835\udc93\ud835\udc93\ud835\udc9a\ud835\udc9a \\\\  \ud835\udc93\ud835\udc93\ud835\udc9b\ud835\udc9b \\end{bmatrix}$",
#         "notes": [
#             "This vector must be relative to some coordinate system origin.",
#             "The SI unit for position is the meter (m)."
#         ]
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Displacement Vector",
#         "definition": "Displacement is the vector change in position of an object.",
#         "equation": "$\ud835\udeab\ud835\udeab\ud835\udc93\ud835\udc93\u122c\u20d7 = \\begin{bmatrix} \ud835\udeab\ud835\udeab\ud835\udc93\ud835\udc93\ud835\udc99\ud835\udc99 \\\\  \ud835\udeab\ud835\udeab\ud835\udc93\ud835\udc93\ud835\udc9a\ud835\udc9a \\\\  \ud835\udeab\ud835\udeab\ud835\udc93\ud835\udc93\ud835\udc9b\ud835\udc9b \\end{bmatrix}$",
#         "notes": [
#             "\u0394\ud835\udc5f\ud835\udc5f\u20d7 = \ud835\udc5f\ud835\udc5f\u20d72 \u2212 \ud835\udc5f\ud835\udc5f\u20d71, meaning that only the final and initial positions are required for the displacement."
#         ]
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Velocity",
#         "definition": "Velocity is the time rate of change of position.",
#         "equation": "$\ud835\udc97\ud835\udc97\u122c\u122c\u20d7 = \ud835\udc85\ud835\udc85\ud835\udc93\ud835\udc93\u122c\u20d7 / \ud835\udc85\ud835\udc85\ud835\udc85\ud835\udc85 = \\begin{bmatrix} \ud835\udc85\ud835\udc85\ud835\udc93\ud835\udc99\ud835\udc99 / \ud835\udc85\ud835\udc85\ud835\udc85\ud835\udc85 \\\\  \ud835\udc85\ud835\udc85\ud835\udc93\ud835\udc93\ud835\udc9a\ud835\udc9a / \ud835\udc85\ud835\udc85\ud835\udc85\ud835\udc85 \\\\  \ud835\udc85\ud835\udc85\ud835\udc93\ud835\udc93\ud835\udc9b\ud835\udc9b / \ud835\udc85\ud835\udc85\ud835\udc85\ud835\udc85 \\end{bmatrix}$",
#         "notes": [
#             "The SI unit for velocity and speed is m/s.",
#             "Instantaneous speed can be found as the magnitude of the velocity vector.",
#             "The average velocity of an object can be found as \ud835\udc63\ud835\udc63\u20d7\ud835\udc4e\ud835\udc4e\ud835\udc4e\ud835\udc4e\ud835\udc4e\ud835\udc4e= \u0394\ud835\udc5f\ud835\udc5f\u20d7/\u0394\ud835\udc61\ud835\udc61."
#         ]
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Acceleration",
#         "definition": "Acceleration is the time rate of change of velocity.",
#         "equation": "$\ud835\udc82\ud835\udc82\u122c\u122c\u20d7 = \ud835\udc85\ud835\udc85\ud835\udc97\ud835\udc97\u122c\u122c\u20d7 / \ud835\udc85\ud835\udc85\ud835\udc85\ud835\udc85 = \\begin{bmatrix} \ud835\udc85\ud835\udc85\ud835\udc97\ud835\udc99\ud835\udc99 / \ud835\udc85\ud835\udc85\ud835\udc85\ud835\udc85 \\\\  \ud835\udc85\ud835\udc85\ud835\udc97\ud835\udc9a\ud835\udc9a / \ud835\udc85\ud835\udc85\ud835\udc85\ud835\udc85 \\\\  \ud835\udc85\ud835\udc85\ud835\udc97\ud835\udc9b\ud835\udc9b / \ud835\udc85\ud835\udc85\ud835\udc85\ud835\udc85 \\end{bmatrix}$",
#         "notes": [
#             "The SI unit of acceleration is m/s\u00b2.",
#             "The average acceleration of an object can be found as \ud835\udc4e\ud835\udc4e\u20d7\ud835\udc4e\ud835\udc4e\ud835\udc4e\ud835\udc4e\ud835\udc4e\ud835\udc4e= \u0394\ud835\udc63\ud835\udc63\u20d7/\u0394\ud835\udc61\ud835\udc61.",
#             "Acceleration is always a vector. If you are discussing the scalar form of acceleration it is the magnitude of the acceleration."
#         ]
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Kinetic Energy",
#         "definition": "Kinetic Energy is the energy of motion, and depends only on an object\u2019s mass and speed.",
#         "equation": "$\ud835\udc72\ud835\udc72 = (\ud835\udf38\\gamma - 1\ud835\udfcf)\ud835\udc8e\ud835\udc8e\ud835\udc84\ud835\udc84^2$",
#         "notes": [
#             "\ud835\udf38\ud835\udf38 = (1\u2212\ud835\udc97\ud835\udc97^2/\ud835\udc84\ud835\udc84^2 )^(\u22121/2)"
#         ]
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Kinetic Energy (Classical Limit)",
#         "definition": "This equation describes the classical kinetic energy of an object of mass, \ud835\udc5a\ud835\udc5a and speed, \ud835\udc63\ud835\udc63.",
#         "equation": "$\ud835\udc72\ud835\udc72 = \\frac{1}{2} \ud835\udc8e\ud835\udc8e \ud835\udc97\ud835\udc97^2$",
#         "notes": [
#             "This equation can be used when \ud835\udc63\ud835\udc63 < ~3\u00d710^6 m/s.",
#             "\ud835\udc63\ud835\udc63^2 = \ud835\udc63\ud835\udc63\u20d7\u22c5\ud835\udc63\ud835\udc63\u20d7."
#         ]
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Gravitational Potential Energy",
#         "definition": "This equation describes the gravitational potential energy, Ug, stored between two masses, m1 and m2, whose centers of mass are separated by a distance, r12.",
#         "equation": "$Ug = -G * m1 * \\frac{m2}{r12}$",
#         "notes": [
#             "The reference frame for this equation is set so that Ug = 0 when r12 = \u221e.",
#             "The constant of proportionality, G, is known as the universal gravitational constant and has a value G = 6.67 x 10^-11 m^3 kg^-1 s^-2."
#         ]
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Gravitational Field",
#         "definition": "The equation describes the gravitational field, g\u20d7, of a large, spherical object of mass, m, a distance r12 from the center of mass of the object.",
#         "equation": "$\\mathbf{g} = -G * \\frac{m}{r12}\u00b2 r\u030212$",
#         "notes": [
#             "This equation assumes we are outside the radius of the object.",
#             "The reference frame for this equation is set so that g\u20d7 = 0 when r12 = \u221e."
#         ]
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Gravitational Field Strength",
#         "definition": "The gravitational field strength, g, is the magnitude of the gravitational field, |g\u20d7|, and is always a positive number.",
#         "equation": "$g = 9.80 \\frac{m}{s}\u00b2 near the surface of the Earth$",
#         "notes": []
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Gravitational Potential Energy (approximation near large body)",
#         "definition": "This equation describes the gravitational potential energy of a mass, m, in a gravitational field strength, g, and height h.",
#         "equation": "$Ug = m * g * h$",
#         "notes": [
#             "The reference frame for this equation is arbitrary and must be kept consistent for a given system.",
#             "In order to use this approximation, g must be approximately constant over all values of h for a given system; therefore \u0394h must be much smaller than the radius of the large body."
#         ]
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Conservation of Energy (COE)",
#         "definition": "COE can be used to solve problems with gravitational potential energy and kinetic energy.",
#         "equation": "$$",
#         "notes": []
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Potential Energy Diagram",
#         "definition": "A graphical representation that shows how the potential energy of an object changes with position.",
#         "equation": "$$",
#         "notes": [
#             "Allows determination of where the object is allowed to be in space when total energy is included.",
#             "Helps visualize how the speed of the object changes at different positions based on total energy, potential energy, and conservation of energy."
#         ]
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Conservation of Energy",
#         "definition": "A principle stating that the total energy of an isolated system remains constant over time.",
#         "equation": "$K(x) = E - U(x)$",
#         "notes": [
#             "K(x) is the kinetic energy, E is the total energy, and U(x) is the potential energy."
#         ]
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Elastic Potential Energy",
#         "definition": "The energy stored when an object, like a spring, is displaced from its equilibrium position.",
#         "equation": "$Us = \\frac{1}{2} ks |\\mathbf{x} - \\mathbf{x}0|^2$",
#         "notes": [
#             "This equation describes the elastic potential energy Us in terms of the stiffness (spring constant) ks and the displacement from equilibrium x - x0.",
#             "This equation is valid for systems that store energy according to the linear version of Hooke\u2019s law.",
#             "The coordinate system can often be set up so that x0 = 0.",
#             "The spring constant ks has units of either J/m^2 or N/m.",
#             "Bonds between atoms act like springs in terms of energy storage."
#         ]
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Temperature",
#         "definition": "Temperature is defined in terms of the average translational kinetic energy of a group of molecules.",
#         "equation": "$K_avg = (\\frac{3}{2}) * k_b * T$",
#         "notes": [
#             "k_b is the Boltzmann constant and has value k_b = 1.381x10^-23 J/K = 8.617x10^-5 eV/K",
#             "T must be measured in Kelvin."
#         ]
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Internal Energy",
#         "definition": "The internal energy, U, of a substance describes all of the microscopic energy stored in motion and bonds.",
#         "equation": "$$",
#         "notes": [
#             "Internal energy is composed of thermal energy and latent energy."
#         ]
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Thermal Energy of Gases",
#         "definition": "This equation defines the thermal energy of a system in terms of the number of particles in the system, the degrees of freedom for the system, and the energy for each degree of freedom.",
#         "equation": "$U_Th = (\\frac{Nf}{2}) * k_b * T$",
#         "notes": [
#             "f = 3 for an ideal monatomic gas and simple solids",
#             "f = 5 for diatomic gases including rotation",
#             "f = 7 for diatomic gases including rotation and vibration"
#         ]
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Change in Thermal Energy",
#         "definition": "This equation relates the change in thermal energy of a system to its mass, specific heat, and change in temperature.",
#         "equation": "$\u0394U_Th = mc\u0394T$",
#         "notes": [
#             "\u0394T can be in Kelvin or Celsius since both scales have the same gradations."
#         ]
#     },
#     {
#         "unit": "Unit 105 explores ways in which we can precisely describe the relative ideas of position and motion.  In this unit, we will",
#         "section": "Bare Essentials",
#         "concept": "Latent Energy",
#         "definition": "Latent energy describes how energy is stored between molecules in a system (non-bond interactions and bonds).",
#         "equation": "$\u0394U_L = \u00b1mL$",
#         "notes": [
#             "For melting and freezing, use the latent heat of fusion, L_f",
#             "For boiling and condensing, use the latent heat of vaporization, L_v",
#             "\u0394U_L is positive for melting/vaporizing and negative for freezing/condensing."
#         ]
#     },
#     {
#         "unit": "Unit 109 introduces rotational motion and the kinetic energy of rotation.  In order to accomplish this, we will discuss",
#         "section": "Bare Essentials",
#         "concept": "Arc Length",
#         "definition": "The arc length is the distance traced out by a point rotating \u03b8 radians around a circle of radius r.",
#         "equation": "$s = r\u03b8$",
#         "notes": [
#             "\u03b8 must be in radians."
#         ]
#     },
#     {
#         "unit": "Unit 109 introduces rotational motion and the kinetic energy of rotation.  In order to accomplish this, we will discuss",
#         "section": "Bare Essentials",
#         "concept": "Angular Speed",
#         "definition": "The angular speed of a rotating rigid object is related to the linear speed of a point on that body by its distance to the axis of rotation.",
#         "equation": "$\u03c9 = \\frac{v}{r}$",
#         "notes": [
#             "\u03c9 = d\u03b8/dt",
#             "The SI units of angular speed is radian/second (rad/sec)."
#         ]
#     },
#     {
#         "unit": "Unit 109 introduces rotational motion and the kinetic energy of rotation.  In order to accomplish this, we will discuss",
#         "section": "Bare Essentials",
#         "concept": "Moment of Inertia",
#         "definition": "The moment of inertia of an object describes its rotational inertia \u2013 its ability to resist changes in rotation.",
#         "equation": "$I = \u222br\u00b2dm$",
#         "notes": [
#             "The integral represents a sum of all tiny pieces of mass, dm, a distance, r, from the axis of rotation.",
#             "The SI units for I is kg\u00b7m\u00b2."
#         ]
#     },
#     {
#         "unit": "Unit 109 introduces rotational motion and the kinetic energy of rotation.  In order to accomplish this, we will discuss",
#         "section": "Bare Essentials",
#         "concept": "Rotational Kinetic Energy",
#         "definition": "The rotational kinetic energy of a rigid body depends on its moment of inertia and its angular speed.",
#         "equation": "$K_rot = \\frac{1}{2} I\u03c9\u00b2$",
#         "notes": [
#             "This equation can only be used for particles or rigid bodies.",
#             "This equation should only be used in the classical limit."
#         ]
#     },
#     {
#         "unit": "Unit 109 introduces rotational motion and the kinetic energy of rotation.  In order to accomplish this, we will discuss",
#         "section": "Bare Essentials",
#         "concept": "Rolling Without Slipping",
#         "definition": "If an object is rolling without slipping, the linear speed of its center of mass is related to its angular speed by v_cm = \u03c9r, where r is the radius of the object. An object that is rolling without slipping contains both linear and rotational kinetic energy.",
#         "equation": "$K_total = K_trans + K_rot = \\frac{1}{2} mv_cm\u00b2 + \\frac{1}{2} I\u03c9\u00b2$",
#         "notes": []
#     },
#     {
#         "unit": "Unit 109 introduces rotational motion and the kinetic energy of rotation.  In order to accomplish this, we will discuss",
#         "section": "Bare Essentials",
#         "concept": "Conservation of Energy in Rotation",
#         "definition": "Solving conservation of energy problems including rotational energy, which involves kinetic energy, gravitational potential energy, elastic potential energy, thermal energy, and rotational energy in rotation.",
#         "equation": "$$",
#         "notes": []
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Force",
#         "definition": "A force describes a push or pull on an object. The force on an object is related to the spatial rate of change of the potential energy of the object.",
#         "equation": "$$",
#         "notes": []
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Force from Potential Energy",
#         "definition": "This equation relates how an average component of force along the x-axis arises from a change in potential energy, which varies in space.",
#         "equation": "$F_x \\\\ ave = -\u0394U/\u0394x$",
#         "notes": [
#             "This equation can be used for any dimension, but it must be used for one-dimensional motion."
#         ]
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Equilibrium Position",
#         "definition": "Regions on a potential energy graph where the force is zero. If the potential energy is at a minimum this is a stable equilibrium. If the potential energy is at a maximum it is an unstable equilibrium.",
#         "equation": "$$",
#         "notes": []
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Dot Product or Scalar Product",
#         "definition": "A vector multiplication that relates components of two vectors which are parallel to each other.",
#         "equation": "$\\mathbf{a} . \\mathbf{b} = a_x b_x + a_y b_y + a_z b_z$ \\quad $\\mathbf{a} . \\mathbf{b} = |\\mathbf{a}| |\\mathbf{b}| cos \u03b8$",
#         "notes": [
#             "The first version of the dot product is often used if you know the components of the vectors.",
#             "The second version is often used if you know the magnitude of the vectors and the angle between them.",
#             "Combining the first and second versions allows you to find the angle between two vectors."
#         ]
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Mechanical Work (constant force)",
#         "definition": "This equation describes the work done by a constant force over a displacement.",
#         "equation": "$W = \\mathbf{F} \u2219 \\mathbf{d}$",
#         "notes": []
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Mechanical Work (non-constant force)",
#         "definition": "This equation describes the work done by a force over a small displacement.",
#         "equation": "$W = \u222b \\mathbf{F} \u22c5 \\mathbf{dx} from a to b$",
#         "notes": [
#             "a and b represent initial and final positions of the displacement."
#         ]
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Work",
#         "definition": "A measure of how much mechanical energy is transferred into or out of a system as a force acts over a displacement or distance.",
#         "equation": "$$",
#         "notes": [
#             "Work is not energy itself, but is a measure of how much mechanical energy is transferred.",
#             "Positive work on a system represents energy transferred into the system.",
#             "Negative work on a system represents energy transferred out of a system.",
#             "Positive work by a system represents energy transferred out of the system.",
#             "Negative work by the system represents energy transferred into the system."
#         ]
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Work due to Conservative Force",
#         "definition": "The work due to a conservative force is independent of the path taken. A conservative force is dependent only on the position of the object. Work due to a conservative force can be stored as potential energy.",
#         "equation": "$$",
#         "notes": []
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Work due to Non-conservative Force",
#         "definition": "The work due to a non-conservative force depends on the path used in calculating the work. Often leads to mechanical energy loss that cannot be recovered.",
#         "equation": "$$",
#         "notes": [
#             "Work due to friction is an example of work due to a non-conservative force."
#         ]
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Conservation of Energy (1st Law of Thermodynamics)",
#         "definition": "This principle states that the change in energy of a system (\u2206E) is equal to the energy transferred into the system by heat (Q) and energy transferred into the system by work (W).",
#         "equation": "$\u2206E = Q + W$",
#         "notes": [
#             "Both Q and W represent energy transfers into the system. If they transfer energy out, values are negative."
#         ]
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Mechanical Energy",
#         "definition": "The sum of potential and kinetic energies in a system.",
#         "equation": "$$",
#         "notes": []
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Conservation of Mechanical Energy",
#         "definition": "The change in mechanical energy of a system is equal to the mechanical work done on the system.",
#         "equation": "$\u2206Em = W$",
#         "notes": [
#             "W represents energy transfer into the system. If mechanical energy transfers out, W is negative."
#         ]
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Work-Kinetic Energy Theorem",
#         "definition": "The net work done on a particle (or non-deformable object) is equal to its total change in kinetic energy.",
#         "equation": "$Wnet = \u2206K$",
#         "notes": [
#             "Net work contains work due to both conservative and non-conservative forces."
#         ]
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Calorie and Kilocalorie",
#         "definition": "Units for measuring heat. One calorie is equivalent to 4.184 joules, and one kilocalorie (Calorie) is equivalent to 4,184 joules.",
#         "equation": "$1 cal = 4.184 J \\\\  1 kcal = 1 Cal = 4 \\\\ 184 J$",
#         "notes": [
#             "Two commonly used units for heat."
#         ]
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Adenosine Triphosphate (ATP)",
#         "definition": "A biomolecule that stores energy essential for the conversion of chemical energy to mechanical energy.",
#         "equation": "$$",
#         "notes": [
#             "Energy storage of ATP is 29 kJ/kg.",
#             "ATP is produced in the mitochondria of cells."
#         ]
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Energy Balance",
#         "definition": "A measure of energy intake versus energy expenditure. Excess energy is stored as adipose tissue (fat).",
#         "equation": "$\u2206E_stored = E_food - E_exercise$",
#         "notes": [
#             "Excess energy is stored as adipose tissue (fat)."
#         ]
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Basal Metabolic Rate (BMR) / Resting Energy Expenditure (REE)",
#         "definition": "A measure of how much energy the body requires at minimum effort, estimated based on gender, height, weight, and age.",
#         "equation": "$$",
#         "notes": [
#             "Can be estimated by the Harris-Benedict Formula or the Mifflin Formula."
#         ]
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "One Pound of Adipose Tissue",
#         "definition": "Stores 3,500 Calories (kcal) of energy.",
#         "equation": "$$",
#         "notes": []
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Nuclear Binding Energy",
#         "definition": "Energy resulting from the mass deficit when protons and neutrons form a nucleus.",
#         "equation": "$\u2206E = \u2206mc^{2}$",
#         "notes": [
#             "The mass deficit is the difference between the mass of the constituent particles and the mass of the nucleus."
#         ]
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Binding Energy per Nucleon",
#         "definition": "The binding energy of a nucleus divided by the total number of nucleons (protons and neutrons).",
#         "equation": "$\u2206e = \u2206E / (n_p + n_n)$",
#         "notes": [
#             "The binding energy per nucleon peaks at iron-56, indicating stability."
#         ]
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Power",
#         "definition": "Power is the time rate of change of energy for a particle or a system.",
#         "equation": "$P = \\frac{dE}{dt}$",
#         "notes": [
#             "Power can be defined as the rate of change of any type of energy with respect to time be it potential, kinetic or internal energy.",
#             "The SI unit of power is the Watt (W)."
#         ]
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Horsepower",
#         "definition": "Horsepower is a non-standard, historical unit of power.",
#         "equation": "$1 hp = 745.7 W$",
#         "notes": []
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Kilowatt-hour",
#         "definition": "The kilowatt-hour is a unit of energy often used to measure electricity usage in residential and commercial systems.",
#         "equation": "$1 kWh = 3.6 x 10^6 J = 3.6 MJ$",
#         "notes": []
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Power From Force and Velocity",
#         "definition": "This equation relates how much energy per second (power) is transformed as a specific force, F, acts on an object moving with velocity, v.",
#         "equation": "$P = \\mathbf{F}\u00b7\\mathbf{v}$",
#         "notes": [
#             "F\u20d7 must be constant over the time interval used for the equation to hold."
#         ]
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Center of Mass",
#         "definition": "The center of mass of an extended object is the average position of its mass, calculated by summing the small portions of mass times their positions relative to the total mass.",
#         "equation": "$\ud835\udc93\u122c\u20d7\ud835\udc84\ud835\udc8e= (1/\ud835\udc40) \u03a3\ud835\udc8e\ud835\udc8a\ud835\udc93\u122c\u20d7\ud835\udc8a$",
#         "notes": [
#             "For linear motion, an extended object can be treated as if all its mass is concentrated at its center of mass."
#         ]
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Momentum of a Particle",
#         "definition": "The momentum of a particle is defined by its mass and velocity, considering the relativistic effects if necessary with the Lorentz factor.",
#         "equation": "$\ud835\udc91\u122c\u122c\u20d7= \ud835\udf38\ud835\udc8e\ud835\udc97\u122c\u122c\u20d7$",
#         "notes": [
#             "In the classical limit, the momentum of a particle is \ud835\udc5d\u20d7= \ud835\udc5a\ud835\udc63\u20d7.",
#             "The SI units of momentum are \ud835\udc58\ud835\udc54\u2219\ud835\udc5a/\ud835\udc60."
#         ]
#     },
#     {
#         "unit": "Unit 110 introduces some relationships between forces and energy transfer.  Along the way, we will define work as the",
#         "section": "Bare Essentials",
#         "concept": "Impulse-Momentum Relationship",
#         "definition": "The impulse-momentum relationship states that the impulse on an object is equal to its change in momentum.",
#         "equation": "$\ud835\udc71\u20d7= \ud835\udeab\ud835\udc91\u122c\u122c\u20d7$",
#         "notes": [
#             "Impulse is defined as the integral of force with respect to time or the average force multiplied by time: \ud835\udc3d\u20d7\u2261\u222b\ud835\udc39\u20d7\ud835\udc51\ud835\udc61\u2248 \ud835\udc39\u20d7\u0bd4\u0be9\u0bd8\u2206\ud835\udc61.",
#             "In practice, the definition of impulse is used to relate to the change in momentum as \ud835\udc39\u20d7\u0bd4\u0be9\u0bd8\u2206\ud835\udc61= \u2206\ud835\udc5d\u20d7."
#         ]
#     },
#     {
# ...
#         "notes": [
#             "A is the cross-sectional area of the object parallel to the force",
#             "G is the shear modulus of the material"
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Bulk Modulus",
#         "definition": "Measures a substance's resistance to uniform compression. It is the ratio of volume stress to volume strain (change in volume).",
#         "equation": "$$",
#         "notes": []
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Bulk (Volume) Deformation",
#         "definition": "Relates the change in volume, \u2206V, to the initial volume of an object, V\u2080, while under a force per unit area, F/A, acting on the object from all sides.",
#         "equation": "$\u0394V = (\\frac{1}{K}) (\\frac{F}{A}) V\u2080$",
#         "notes": [
#             "K is the bulk modulus of the material"
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Common States of Matter",
#         "definition": "The three most common states of matter are solids, liquids, and gases.",
#         "equation": "$$",
#         "notes": [
#             "Solid: Molecules are locked into place, making the material rigid, although it can be deformed by external forces.",
#             "Liquid: Molecules are free to move relative to each other, but intermolecular forces keep them close. Liquids flow, but their density remains relatively constant under pressure.",
#             "Gas: Molecules are free to move and interact weakly, allowing gases to flow and change density due to external pressure."
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Pressure",
#         "definition": "Pressure is a measure of how much force is distributed over an area.",
#         "equation": "$P = |\\mathbf{dF}N| / dA$",
#         "notes": [
#             "The standard unit of pressure is the Pascal, where 1 Pa = 1 N/m\u00b2.",
#             "A commonly used unit for pressure is the atmosphere (atm), where 1 atm = 101.3 kPa."
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Variation of Pressure with Depth",
#         "definition": "Pressure varies with depth due to gravity.",
#         "equation": "$P = P0 + \u03c1gh$",
#         "notes": [
#             "P is the pressure at depth h below a point where the pressure is known to be P0.",
#             "\u03c1 is the density of the fluid.",
#             "g is the gravitational field strength."
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Force of Buoyancy",
#         "definition": "The force of buoyancy is derived from the variation of pressure with depth.",
#         "equation": "$FB = \u03c1fluid g Vdisplaced$",
#         "notes": [
#             "FB is the buoyant force for an object submerged displacing a volume Vdisplaced of fluid with density \u03c1fluid.",
#             "g is the gravitational field strength.",
#             "The force of buoyancy is directed towards lower pressure, usually, but not always, upwards."
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Ideal Fluid",
#         "definition": "A fluid that is incompressible, exhibits steady, non-rotational flow, and ignores viscosity.",
#         "equation": "$$",
#         "notes": [
#             "An ideal fluid cannot include gases because it must be incompressible."
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Continuity Equation",
#         "definition": "The volume flow rate, Q, of an ideal fluid is equal to the velocity of the fluid multiplied by the cross-sectional area of the flow. The continuity equation states that the volume flow rate of an ideal fluid is constant.",
#         "equation": "$Q = vA = constant \u21d2 v1A1 = v2A2$",
#         "notes": [
#             "This equation only holds for incompressible fluids.",
#             "The units for volume flow rate is m\u00b3/s."
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Bernoulli\u2019s Equation",
#         "definition": "Bernoulli\u2019s equation states that the sum of the pressure in a fluid, kinetic energy density, and gravitational potential energy density in a fluid is constant for the entire fluid flow.",
#         "equation": "$P1 + \\frac{1}{2} \u03c1v1\u00b2 + \u03c1gz1 = P2 + \\frac{1}{2} \u03c1v2\u00b2 + \u03c1gz2$",
#         "notes": [
#             "This only holds for ideal fluids."
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Viscosity",
#         "definition": "Viscosity is a measure of friction in a fluid.",
#         "equation": "$\u03b7 = \\frac{Fy}{v}\u2080A$",
#         "notes": [
#             "This equation defines the viscosity of a fluid as found by placing the fluid between two flat plates.",
#             "F is the force it takes to keep the upper plate a fixed distance, y, above a stationary plate of cross-sectional area, A, moving at a speed, v\u2080, relative to the stationary plate.",
#             "The unit of viscosity is Pa\u22c5s."
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Poiseuille\u2019s Law",
#         "definition": "Poiseuille\u2019s Law tells us how a difference in pressure between two points (1 and 2) is related to the volume flow rate of a fluid, the fluid viscosity, and the length and radius of the tube the fluid flows in.",
#         "equation": "$P\u2081\u2212P\u2082 = 8\u03b7LQ / \u03c0r\u2074$",
#         "notes": [
#             "It describes how pressure decreases in a real fluid as it flows and how a difference in pressure can cause a fluid flow."
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Reynolds\u2019s Number for Tube Flow",
#         "definition": "Reynolds\u2019s Number helps us determine whether a flow is laminar or turbulent for fluid flow in a tube.",
#         "equation": "$R\u2091 = 2\u03c1vr / \u03b7$",
#         "notes": [
#             "This equation defines the Reynold\u2019s Number for fluid flow in a tube of radius r in terms of the density of the fluid, \u03c1, the speed of the fluid flow, v, and the viscosity of the fluid, \u03b7.",
#             "Flow is laminar if R\u2091 < 2000, unstable if R\u2091 is between 2000 and 3000, and turbulent if R\u2091 > 3000."
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Reynolds\u2019s Number for Object Moving in a Fluid",
#         "definition": "Reynolds\u2019s Number helps us determine whether flow behind an object is laminar, unstable, or exhibits a turbulent wake in a fluid.",
#         "equation": "$R'\u2091 = \u03c1vL / \u03b7$",
#         "notes": [
#             "This equation defines the Reynold\u2019s Number for an object in a fluid in terms of the density of the fluid, \u03c1, the speed of the object, v, a characteristic length of the object, L, and the viscosity of the fluid, \u03b7.",
#             "Flow behind the object is laminar if R'\u2091 < 1, unstable if R'\u2091 is between 1 and 10\u2076, and exhibits a turbulent wake if R'\u2091 > 10\u2076.",
#             "You must be very careful with the variable definitions as they are not as standard for real fluids as in other areas of introductory physics.",
#             "Each equation box explicitly defines the variables used."
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Derivative of a Function",
#         "definition": "The derivative of a function of a single variable represents the rate of change of the function at a given point. On a graph, the derivative of a function is the slope of the function at a given point. The mathematical definition of the derivative gives us a way to find the desired rate of change of any function.",
#         "equation": "$f'(t) = df(t)/dt = lim (h\u21920) [f(t+h) - f(t)]/h$",
#         "notes": [
#             "In practice, using the definition can be very hard.",
#             "Two common notations for a derivative are f'(t) and df(t)/dt.",
#             "The definition is often given as a derivative with respect to time, but could be with respect to other variables such as x."
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Basic Derivatives",
#         "definition": "Derivative formulas for common basic functions.",
#         "equation": "$\\frac{d}{dt}(n) = 0 \\\\  \\frac{d}{dt}(t^n) = nt^{n-1} \\\\  \\frac{d}{dt}(sin nt) = n cos nt \\\\  \\frac{d}{dt}(cos nt) = -n sin nt \\\\  \\frac{d}{dt}(e^{nt}) = n e^{nt}$",
#         "notes": [
#             "n represents any constant value and t is the variable for these examples."
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Constant Multiple Rule",
#         "definition": "When a constant multiplies a function, the constant can be factored out of the derivative.",
#         "equation": "$\\frac{d}{dt}(nf(t)) = n df(t)/dt$",
#         "notes": []
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Sum Rule in Derivatives",
#         "definition": "The sum rule tells us that if we have the sum of two functions, the derivative of the sum is the sum of the derivatives of the individual functions.",
#         "equation": "$d[f(t) + g(t)]/dt = f'(t) + g'(t)$",
#         "notes": [
#             "This rule is for two functions of a single variable f(t) and g(t), which are added together."
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Product Rule in Derivatives",
#         "definition": "The product rule gives us a way of finding the derivative of two functions of a single variable multiplied together.",
#         "equation": "$d[f(t)g(t)]/dt = f'(t)g(t) + f(t)g'(t)$",
#         "notes": [
#             "This rule is for two functions of a single variable f(t) and g(t), which are multiplied together."
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Higher Order Derivatives",
#         "definition": "Higher order derivatives are obtained by taking consecutive derivatives of a function.",
#         "equation": "$First derivative: x'(t) = \\frac{dx}{dt} \\\\  Second derivative: x''(t) = \\frac{d}{dt} \\begin{bmatrix} x'(t)] \\\\  Third derivative: x'''(t) = \\frac{d}{dt} [x''(t) \\end{bmatrix} \\\\  etc.$",
#         "notes": []
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Antiderivative",
#         "definition": "The antiderivative of a function \ud835\udc53(\ud835\udc61) is a function \ud835\udc54(\ud835\udc61) such that its derivative is \ud835\udc53(\ud835\udc61).",
#         "equation": "$\u222b\ud835\udc53(\ud835\udc61)\ud835\udc51\ud835\udc61 = \ud835\udc54(\ud835\udc61)$",
#         "notes": [
#             "The antiderivative is only defined up to a constant.",
#             "Indefinite integrals must include a constant term, e.g., \u222b\ud835\udc61\u00b2\ud835\udc51\ud835\udc61 = \ud835\udc61\u00b3/3 + \ud835\udc36."
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Definite Integral",
#         "definition": "The definite integral of a function is the antiderivative of that function evaluated over a specific region.",
#         "equation": "$$",
#         "notes": [
#             "Graphically represents the area under the curve of the function between two points."
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Fundamental Theorem of Calculus",
#         "definition": "The theorem states that the integral of a derivative function \ud835\udc53\u2019(\ud835\udc61) over an interval is equal to the difference of the values of the original function \ud835\udc53(\ud835\udc61) at the endpoints.",
#         "equation": "$\u222b[a to b] \ud835\udc53'(\ud835\udc61)\ud835\udc51\ud835\udc61 = \ud835\udc53(\ud835\udc4f) \u2212 \ud835\udc53(\ud835\udc4e)$",
#         "notes": [
#             "The antiderivative of the integrand must be known to compute the integral from this theorem."
#         ]
#     },
#     {
#         "unit": "Unit 129 we now explore how the release of elastic potential energy may lead to vibrational motion.  Along the way,",
#         "section": "Bare Essentials",
#         "concept": "Important Antiderivatives",
#         "definition": "Common antiderivatives to know for basic functions with respect to \ud835\udc61.",
#         "equation": "$$",
#         "notes": [
#             "\u222b\ud835\udc4e\ud835\udc51\ud835\udc61 = \ud835\udc4e\ud835\udc61 + \ud835\udc36",
#             "\u222b\ud835\udc61\u207f\ud835\udc51\ud835\udc61 = \ud835\udc61\u207f\u207a\u00b9/(\ud835\udc5b+1) + \ud835\udc36",
#             "\u222bsin(\ud835\udc4e\ud835\udc61)\ud835\udc51\ud835\udc61 = \u22121/\ud835\udc4e cos(\ud835\udc4e\ud835\udc61) + \ud835\udc36",
#             "\u222bcos(\ud835\udc4e\ud835\udc61)\ud835\udc51\ud835\udc61 = 1/\ud835\udc4e sin(\ud835\udc4e\ud835\udc61) + \ud835\udc36",
#             "\u222b\ud835\udc52\u1d43\u1d57\ud835\udc51\ud835\udc61 = 1/\ud835\udc4e \ud835\udc52\u1d43\u1d57 + \ud835\udc36"
#         ]
#     }
# ]

# %%
def clean_latex_equation(equation):
    """
    Cleans LaTeX equations by:
    - Fixing fraction formatting.
    - Ensuring proper subscripts and superscripts.
    - Removing duplicate character encoding errors.
    - Standardizing matrix formatting.
    """

    if not equation or equation.strip() in ["$$", "$ $", "$$ $$"]:
        return ""

    # Ensure LaTeX math wrapping
    if not equation.startswith("$"):
        equation = f"${equation}$"

    # Remove duplicate Unicode characters (e.g., "𝒓𝒓" → "𝒓")
    equation = re.sub(r"([a-zA-Z𝒓𝚫𝑲𝒗𝑭𝒂𝒑𝒎𝑻𝑼𝝉𝒓𝑳𝜽𝜌𝑮𝒈])\1", r"\1", equation)

    # Convert Unicode superscripts and subscripts to LaTeX format
    equation = re.sub(r"([a-zA-Z])(\d+)", r"\1_{\2}", equation)  # Fix subscripts (x1 → x_1)
    equation = re.sub(r"(\w+)\^(\d+)", r"\1^{\2}", equation)  # Fix superscripts (x^2 → x^{2})

    # Convert inline fractions (a/b → \frac{a}{b})
    equation = re.sub(r"(\w+)\s*/\s*(\w+)", r"\\frac{\1}{\2}", equation)

    # Fix matrix formatting: Ensure proper LaTeX syntax
    equation = equation.replace("\\\\", " \\\\ ")  # Ensure new line spacing in matrices

    return equation.strip()


def post_process_json(json_file, output_file):
    """
    Loads the JSON file, cleans LaTeX equations, and writes the cleaned version to a new file.
    """
    with open(json_file, "r", encoding="utf-8") as f:
        data = json.load(f)

    for entry in data:
        if "equation" in entry and entry["equation"]:
            entry["equation"] = clean_latex_equation(entry["equation"])

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(data, f, indent=4, ensure_ascii=False)

    print(f"Post-processing complete. Cleaned JSON saved to {output_file}")

# %%
# Example usage:
post_process_json("data/json/bare_essentials_concepts.json", "data/json/cleaned_essentials_equations.json")
# Out:
# Post-processing complete. Cleaned JSON saved to data/json/cleaned_essentials_equations.json

# %%
def validate_equations(json_file, log_file="invalid_equations.log"):
    """
    Scans a cleaned JSON file and logs any ill-formed equations for further debugging.
    
    Parameters:
        json_file (str): Path to the cleaned JSON file.
        log_file (str): Path to the log file to store any detected issues.
    """
    logging.basicConfig(filename=log_file, level=logging.WARNING, format="%(asctime)s - %(levelname)s - %(message)s")

    with open(json_file, "r", encoding="utf-8") as f:
        data = json.load(f)

    invalid_equations = []
    
    # Improved regex: Ensures equations start & end with a single `$`, allowing multi-line
    latex_pattern = re.compile(r"^\$(?!\$)[\s\S]*[^$]\$$")

    # Additional checks for LaTeX syntax errors
    bracket_pairs = {"{": "}", "[": "]", "(": ")"}
    latex_functions = [r"\\frac", r"\\begin", r"\\end", r"\\left", r"\\right"]

    for entry in data:
        concept = entry.get("concept", "Unknown Concept")
        equation = entry.get("equation", "").strip()

        if equation:
            # 1. Check for empty or meaningless equations
            if equation in ["$$", "$ $", "$$ $$", "$"] or not equation.strip("$").strip():
                invalid_equations.append(f"Empty equation found for '{concept}': {equation}")

            # 2. Check for missing proper LaTeX math mode ($ at start & end)
            elif not latex_pattern.match(equation):
                invalid_equations.append(f"Equation not properly formatted for '{concept}': {equation}")

            # 3. Check for **UNMATCHED** brackets in LaTeX
            for open_br, close_br in bracket_pairs.items():
                if equation.count(open_br) != equation.count(close_br):
                    invalid_equations.append(f"Unmatched brackets in equation for '{concept}': {equation}")
                    break  # No need to check further if one type is unmatched

            # 4. Detect Incorrect LaTeX Syntax
            for func in latex_functions:
                if re.search(func + r"[^{]", equation):  # Ensure each function is followed by `{`
                    invalid_equations.append(f"Potential LaTeX syntax issue in '{concept}': {equation}")

    # Log issues found
    if invalid_equations:
        logging.warning(f"{len(invalid_equations)} ill-formed equations detected.")
        for eq in invalid_equations:
            logging.warning(eq)
        print(f"Validation complete. Found {len(invalid_equations)} issues. Check '{log_file}' for details.")
    else:
        print("Validation complete. No issues detected.")

# %%
validate_equations("data/json/cleaned_essentials_equations.json", log_file="invalid_equations.log")
# Out:
# Validation complete. No issues detected.

# %%
pdf_path = "data/chapters/Unit 119 - Newtons Laws.pdf"

text_extract_test = utils.extract_text_chunks(pdf_path, output_json="data/json/Unit_119_text.json")
# Out:
# Text extraction complete! Data saved to data/json/Unit_119_text.json

# %%
with open("data/json/Unit_119_text.json", "r") as f:
    data = json.load(f)

print(json.dumps(data, indent=4))
# Out:
# [
#     {
#         "unit": null,
#         "section": null,
#         "chunk_type": "paragraph",
#         "content": "119 \u2013 Newton \u2019 s Laws Newton \u2019 s laws of motion give us another way to analyze physical systems . By using Newton \u2019 s laws , we can directly relate how the net force on a set of objects is related to acceleration . Then , using kinematic relationships studied in the next two units , we will be able to directly relate the acceleration of objects to their change in velocity and position . The Bare Essentials \uf0b7 Isaac Newton proposed three \u2018 laws \u2019 for classical mechanics \uf0b7 Note : Newton \u2019 s laws and free-body diagrams are done with that hold for inertial , non-relativistic systems . respect to individual objects . This is quite different than the conservation of momentum and energy where the equations \uf0b7 Newton \u2019 s 1st law states that the velocity of an object does not were for the entire system ! change if it is not interacting with other objects \uf0b7 The gravitational force on an object is given by mass of the \u201c An object in motion tends to stay in motion object multiplied by the local gravitational field strength . unless acted on by an outside force \u201d \uf0b7 Newton \u2019 s 2nd law relates the net force on an object to its Gravitational Force change in momentum , and often its acceleration . ( cid:4652 ) \ud835\udc6d ( cid:4652 ) \u20d7 =\ud835\udc8e ( cid:4652 ) \ud835\udc88 ( cid:4652 ) \u20d7 \ud835\udc88 Newton \u2019 s Second Law Description : This equation describes the gravitational force on an object , \ud835\udc39 , as the product of the object \u2019 s mass , \ud835\udc5a , ( cid:3034 ) \ud835\udc85\ud835\udc91 ( cid:4652 ) ( cid:4652 ) \u20d7 \ud835\udc05\u20d7 = and the local gravitational field , \ud835\udc54\u20d7 . \ud835\udc27\ud835\udc1e\ud835\udc2d \ud835\udc85\ud835\udc95 Note : Near the surface of the earth , the gravitational field strength is often given as 9.80 \ud835\udc5a/\ud835\udc60 ( cid:2870 ) or 9.80 \ud835\udc41/\ud835\udc58\ud835\udc54 Description \u2013 The equation relates the net force on an object , F ( cid:4652 ) \u20d7 ( cid:2924 ) ( cid:2915 ) ( cid:2930 ) , to the rate of change of the object \u2019 s momentum , \ud835\udc51\ud835\udc5d\u20d7\u2044\ud835\udc51\ud835\udc61 . Note : When the mass of an object moving at non-relativistic speeds is constant , \ud835\udc51\ud835\udc5d\u20d7\u2044\ud835\udc51\ud835\udc61 reduces to \ud835\udc5a\ud835\udc4e\u20d7 . \uf0b7 Newton \u2019 s 3rd law states that since an interaction is between two objects , the force on one of the interacting objects is equal in magnitude and opposite in direction to the force on the other interacting object . \u201c For every action , there is an equal and opposite reaction \u201d \uf0b7 In order to visualize the force on individual object , it is advised that you always draw a free-body diagram of each object in the system and label each diagram with all of the forces that act on the body .",
#         "page": 1
#     },
#     {
#         "unit": "Unit 119",
#         "section": "From conservation laws to Newton\u2019s \u201claws\u201d",
#         "chunk_type": "paragraph",
#         "content": "Consider : Are there other ways to solve physics problems besides the conservation of energy and momentum ? T HE LAWS OF CONSERVATION OF ENERGY AND conservation of momentum that we have studied up to this point give us powerful tools to solve physics problems . As mentioned before , these two principles are not only applicable for classical physics , but can be applied to the very small ( quantum systems ) and the very fast ( relativistic systems ) . Interestingly , there is some question as to the conservation of energy on the very , very large scale \u2013 we \u2019 re not sure that energy conservation works for the universe as a whole . Regardless , the principles of energy and momentum are so pervasive that it is impossible to overstate their important in all of science . There are another set of \u201c laws \u201d that can be used to solve physics problems \u2013 Newton \u2019 s laws of motion . Although often called laws , they are not conservation laws like energy and momentum , but rather a set of rules that work extremely well in the classical limit . As summarized in Unit 103 , the three laws are Newton \u2019 s 1st Law : In an inertial reference frame , an object remains at rest or continues Figure 119-1 . Newton \u2019 s to move at constant velocity ( speed and direction ) unless acted on by an laws from the original outside force . Principia . Newton \u2019 s 2nd Law : The vector sum of forces on an object is equal to the rate of change of momentum of the object . In the case where the mass of the object remains the same , the vector sum of forces is equal to the mass of the object multiplied by the acceleration of the object . Newton \u2019 s 3rd Law : When two objects interact , the force exerted on the first object by the second object is equal in magnitude and opposite in direction to the force on the second object by the first object . In Unit 119 , we explore the basics of these three laws . Units 120 through 122 will explore the particulars of position , velocity and acceleration . Then , units 123 through 129 build up a repertoire of techniques that can be used to solve problems using Newton \u2019 s three laws . We will see along the way that almost all of the problems we solved using energy and momentum can also be solved using forces and Newton \u2019 s laws . The power of knowing each technique is that one problem may be much easier to solve using Newton \u2019 s laws rather than energy considerations , but another problem may be more suited to the energy and momentum principles .",
#         "page": 2
#     },
#     {
#         "unit": "Unit 119",
#         "section": "Inertial reference frames and the law of inertia",
#         "chunk_type": "paragraph",
#         "content": "Consider : Why do objects in motion tend to stay in motion ? Imagine an object which is not undergoing any interactions . For this object , it is possible to find a reference frame in which the object does not accelerate . Such a reference frame is called an inertial reference frame . It is actually possible to find an infinite number of such frames and although the object would not accelerate in any of those frames , the velocity of the object could be different in each . Consider this example : You are traveling down the road at 55 mph relative to the ground . A car , traveling the same direction , passes you traveling at 75 mph relative to the ground . You would say that the car is moving 20 mph faster than you are , which is to say that the car is moving 20 mph relative to you . Both you and the ground represent inertial coordinate systems for the other car . In the coordinate system attached to the ground , the other car is moving at 75 mph . In the coordinate system attached to you , the car is moving 20 mph . The other car is not accelerating in either frame , although the speed of the other car is different in each frame . To be very precise , this example does not help to define inertial reference frames because the other car is undergoing a number of interactions as a rolls down the road . However , the visuals relayed by the cars of this example should give you a feel for why inertial reference frames are helpful . Now that we have a feel for inertial reference frames , we can once again state Newton \u2019 s first law : 168",
#         "page": 2
#     },
#     {
#         "unit": "Unit 119",
#         "section": "Inertial reference frames and the law of inertia",
#         "chunk_type": "paragraph",
#         "content": "Consider : Why do objects in motion tend to stay in motion ? Imagine an object which is not undergoing any interactions . For this object , it is possible to find a reference frame in which the object does not accelerate . Such a reference frame is called an inertial reference frame . It is actually possible to find an infinite number of such frames and although the object would not accelerate in any of those frames , the velocity of the object could be different in each . Consider this example : You are traveling down the road at 55 mph relative to the ground . A car , traveling the same direction , passes you traveling at 75 mph relative to the ground . You would say that the car is moving 20 mph faster than you are , which is to say that the car is moving 20 mph relative to you . Both you and the ground represent inertial coordinate systems for the other car . In the coordinate system attached to the ground , the other car is moving at 75 mph . In the coordinate system attached to you , the car is moving 20 mph . The other car is not accelerating in either frame , although the speed of the other car is different in each frame . To be very precise , this example does not help to define inertial reference frames because the other car is undergoing a number of interactions as a rolls down the road . However , the visuals relayed by the cars of this example should give you a feel for why inertial reference frames are helpful . Now that we have a feel for inertial reference frames , we can once again state Newton \u2019 s first law : 168 Newt on \u2019 s La ws | 119-5 In an inertial reference frame , an object remains at rest or continues to move at constant velocity ( speed and direction ) unless acted on by an outside force . Newton \u2019 s first law is also sometimes called the law of inertia . Inertia is the ability of any object to resist a change in its motion , and since the 1st law is entirely about an object \u2019 s lack of change of motion in the absence of forces , calling it the law of inertia fits well . We will see in Newton \u2019 s 2nd law that an object \u2019 s ability to resist changes in motion is directly proportional to its mass , so an object \u2019 s mass is direct measure of its inertia . This definition of mass can be used to bring even more meaning to the definition of momentum of a particle : \ud835\udc5d\u20d7=\ud835\udefe\ud835\udc5a\ud835\udc63\u20d7 , ( 119-1 ) which is now the ( complex ) product of an object \u2019 s inertia and velocity .",
#         "page": 3
#     },
#     {
#         "unit": "Unit 119",
#         "section": "Newton\u2019s second law",
#         "chunk_type": "paragraph",
#         "content": "Consider : How do forces relate to an object \u2019 s change in motion ? When an object undergoes one or more interactions , the net ( vector ) force on the object is the vector sum of the forces due to each interactions , as \ud835\udc39\u20d7 =\ud835\udc39\u20d7 +\ud835\udc39\u20d7 +\ud835\udc39\u20d7 +\u22ef , ( 119-2 ) ( cid:3041 ) ( cid:3032 ) ( cid:3047 ) ( cid:2869 ) ( cid:2870 ) ( cid:2871 ) where \ud835\udc39\u20d7 , \ud835\udc39\u20d7 , and so on are the forces due to the object \u2019 s interactions . Here , remember that each individual force is the push ( cid:2869 ) ( cid:2870 ) or pull that results from a single interaction . The net force , or vector sum of the forces , is directly related to the change in motion of the object . In fact , the net vector force on an object is equal to the rate of change of the object \u2019 s momentum . \ud835\udc51\ud835\udc5d\u20d7 ( 119-3 ) \ud835\udc39\u20d7 = . ( cid:3041 ) ( cid:3032 ) ( cid:3047 ) \ud835\udc51\ud835\udc61 Equation 119-3 is Newton \u2019 s 2nd law . In the classical limit and if the mass of the object is constant , Newton \u2019 s 2nd law can be further reduced using the definition of momentum as \ud835\udc51\ud835\udc5d\u20d7 \ud835\udc51 ( \ud835\udc5a\ud835\udc63\u20d7 ) \ud835\udc51\ud835\udc63\u20d7 ( 119-4 ) \ud835\udc39\u20d7 = = =\ud835\udc5a =\ud835\udc5a\ud835\udc4e\u20d7 . ( cid:3041 ) ( cid:3032 ) ( cid:3047 ) \ud835\udc51\ud835\udc61 \ud835\udc51\ud835\udc61 \ud835\udc51\ud835\udc61 where we have used the fact that the rate of change of velocity ( time derivative of velocity ) is acceleration . Equation 119-4 is the more commonly known equation for Newton \u2019 s 2nd law ; however , Equation 119-3 , defining the net force in terms of the rate of change of momentum , more closely relates force to the fundamental momentum principle . Newton \u2019 s Second Law \ud835\udc85\ud835\udc91 ( cid:4652 ) ( cid:4652 ) \u20d7 \ud835\udc05\u20d7 = \ud835\udc27\ud835\udc1e\ud835\udc2d \ud835\udc85\ud835\udc95 Description \u2013 The equation relates the net force on an object , F ( cid:4652 ) \u20d7 , to the rate of change of the object \u2019 s ( cid:2924 ) ( cid:2915 ) ( cid:2930 ) momentum , \ud835\udc51\ud835\udc5d\u20d7\u2044\ud835\udc51\ud835\udc61 . Note : When the mass of an object moving at non-relativistic speeds is constant , \ud835\udc51\ud835\udc5d\u20d7\u2044\ud835\udc51\ud835\udc61 reduces to \ud835\udc5a\ud835\udc4e\u20d7 . Imagine an object which undergoes a number of interactions and therefore has a number of forces acting on it . Each force individually would lead to a change in momentum of the object , but is masked because there are numerous forces . We can represent this mathematically as 169",
#         "page": 3
#     },
#     {
#         "unit": "Unit 119",
#         "section": "6 | P h ys i cs",
#         "chunk_type": "paragraph",
#         "content": "Consider : How do forces relate to an object \u2019 s change in motion ? When an object undergoes one or more interactions , the net ( vector ) force on the object is the vector sum of the forces due to each interactions , as \ud835\udc39\u20d7 =\ud835\udc39\u20d7 +\ud835\udc39\u20d7 +\ud835\udc39\u20d7 +\u22ef , ( 119-2 ) ( cid:3041 ) ( cid:3032 ) ( cid:3047 ) ( cid:2869 ) ( cid:2870 ) ( cid:2871 ) where \ud835\udc39\u20d7 , \ud835\udc39\u20d7 , and so on are the forces due to the object \u2019 s interactions . Here , remember that each individual force is the push ( cid:2869 ) ( cid:2870 ) or pull that results from a single interaction . The net force , or vector sum of the forces , is directly related to the change in motion of the object . In fact , the net vector force on an object is equal to the rate of change of the object \u2019 s momentum . \ud835\udc51\ud835\udc5d\u20d7 ( 119-3 ) \ud835\udc39\u20d7 = . ( cid:3041 ) ( cid:3032 ) ( cid:3047 ) \ud835\udc51\ud835\udc61 Equation 119-3 is Newton \u2019 s 2nd law . In the classical limit and if the mass of the object is constant , Newton \u2019 s 2nd law can be further reduced using the definition of momentum as \ud835\udc51\ud835\udc5d\u20d7 \ud835\udc51 ( \ud835\udc5a\ud835\udc63\u20d7 ) \ud835\udc51\ud835\udc63\u20d7 ( 119-4 ) \ud835\udc39\u20d7 = = =\ud835\udc5a =\ud835\udc5a\ud835\udc4e\u20d7 . ( cid:3041 ) ( cid:3032 ) ( cid:3047 ) \ud835\udc51\ud835\udc61 \ud835\udc51\ud835\udc61 \ud835\udc51\ud835\udc61 where we have used the fact that the rate of change of velocity ( time derivative of velocity ) is acceleration . Equation 119-4 is the more commonly known equation for Newton \u2019 s 2nd law ; however , Equation 119-3 , defining the net force in terms of the rate of change of momentum , more closely relates force to the fundamental momentum principle . Newton \u2019 s Second Law \ud835\udc85\ud835\udc91 ( cid:4652 ) ( cid:4652 ) \u20d7 \ud835\udc05\u20d7 = \ud835\udc27\ud835\udc1e\ud835\udc2d \ud835\udc85\ud835\udc95 Description \u2013 The equation relates the net force on an object , F ( cid:4652 ) \u20d7 , to the rate of change of the object \u2019 s ( cid:2924 ) ( cid:2915 ) ( cid:2930 ) momentum , \ud835\udc51\ud835\udc5d\u20d7\u2044\ud835\udc51\ud835\udc61 . Note : When the mass of an object moving at non-relativistic speeds is constant , \ud835\udc51\ud835\udc5d\u20d7\u2044\ud835\udc51\ud835\udc61 reduces to \ud835\udc5a\ud835\udc4e\u20d7 . Imagine an object which undergoes a number of interactions and therefore has a number of forces acting on it . Each force individually would lead to a change in momentum of the object , but is masked because there are numerous forces . We can represent this mathematically as 169 \ud835\udc51\ud835\udc5d\u20d7 \ud835\udc51\ud835\udc5d\u20d7 \ud835\udc51\ud835\udc5d\u20d7 ( 119-4 ) \ud835\udc39\u20d7 =\ud835\udc39\u20d7 +\ud835\udc39\u20d7 +\ud835\udc39\u20d7 +\u22ef= ( cid:2869 ) + ( cid:2870 ) + ( cid:2871 ) +\u22ef . ( cid:3041 ) ( cid:3032 ) ( cid:3047 ) ( cid:2869 ) ( cid:2870 ) ( cid:2871 ) \ud835\udc51\ud835\udc61 \ud835\udc51\ud835\udc61 \ud835\udc51\ud835\udc61",
#         "page": 4
#     },
#     {
#         "unit": "Unit 119",
#         "section": "6 | P h ys i cs",
#         "chunk_type": "paragraph",
#         "content": "Each force individually would lead to a change in momentum of the object , but is masked because there are numerous forces . We can represent this mathematically as 169 \ud835\udc51\ud835\udc5d\u20d7 \ud835\udc51\ud835\udc5d\u20d7 \ud835\udc51\ud835\udc5d\u20d7 ( 119-4 ) \ud835\udc39\u20d7 =\ud835\udc39\u20d7 +\ud835\udc39\u20d7 +\ud835\udc39\u20d7 +\u22ef= ( cid:2869 ) + ( cid:2870 ) + ( cid:2871 ) +\u22ef . ( cid:3041 ) ( cid:3032 ) ( cid:3047 ) ( cid:2869 ) ( cid:2870 ) ( cid:2871 ) \ud835\udc51\ud835\udc61 \ud835\udc51\ud835\udc61 \ud835\udc51\ud835\udc61 Relating this equation back to Unit 114 , each of \ud835\udc51\ud835\udc5d\u20d7 , \ud835\udc51\ud835\udc5d\u20d7 , etc. , represent the impulses on the object due to each individual ( cid:2869 ) ( cid:2870 ) force . Although this relationship will not change the ways in which we find the net force and motion of objects , it can help with the interpretation of why the net force causes a change in motion . As we continue to move from using conservation laws to forces to solve problems , it is important to keep the following in mind : For conservation laws : we combine the entire system into one equation for all objects in the system For Newton \u2019 s 2nd law : we write a 2nd law equation for each object in the system . As such , we will have the same number of ( vector ) equations as we have objects of interest in the system . Example 119 - 1 Net force from two forces An object is acted on by two forces : As you can see , this is the net force as a function of time . The net force at time \ud835\udc61 =3 \ud835\udc60 is found by substituting in \ud835\udc39\u20d7 = ( 10\ud835\udc61\ud835\udea4\u0302\u22123\ud835\udea5\u0302 ) \ud835\udc41 ; the time , giving us ( cid:2869 ) \ud835\udc39\u20d7 = ( cid:3435 ) \u22122\ud835\udea4\u0302+11\ud835\udc61 ( cid:2870 ) \ud835\udea5\u0302+4\ud835\udc58 ( cid:3552 ) ( cid:3439 ) \ud835\udc41 . 28 ( cid:2870 ) \ud835\udc39 = ( cid:3429 ) 96 ( cid:3433 ) \ud835\udc41 . ( cid:3041 ) ( cid:3032 ) ( cid:3047 ) 4 ( a ) What is the net force acting on this object at time \ud835\udc61 =3 \ud835\udc60 ? ( b ) If the object has a mass of 20 kg , what is the acceleration ( b ) Since the mass is given as a constant 20 kg , we can of the object at this time ? write Newton \u2019 s 2nd law as Solution : \ud835\udc51\ud835\udc5d\u20d7 F ( cid:4652 ) \u20d7 F ( cid:4652 ) \u20d7 = =\ud835\udc5a\ud835\udc4e\u20d7 \u2192 \ud835\udc4e\u20d7 = ( cid:2924 ) ( cid:2915 ) ( cid:2930 ) . This problem asks us to find the net force on an object due to ( cid:2924 ) ( cid:2915 ) ( cid:2930 ) \ud835\udc51\ud835\udc61 \ud835\udc5a two individual forces and then to determine the acceleration Therefore , of the object due to those forces . 28 1.4 ( a ) The first step is to use the definition of net force to find 1 \ud835\udc5a",
#         "page": 4
#     },
#     {
#         "unit": "Unit 119",
#         "section": "6 | P h ys i cs",
#         "chunk_type": "paragraph",
#         "content": "= ( cid:2924 ) ( cid:2915 ) ( cid:2930 ) . This problem asks us to find the net force on an object due to ( cid:2924 ) ( cid:2915 ) ( cid:2930 ) \ud835\udc51\ud835\udc61 \ud835\udc5a two individual forces and then to determine the acceleration Therefore , of the object due to those forces . 28 1.4 ( a ) The first step is to use the definition of net force to find 1 \ud835\udc5a \ud835\udc4e\u20d7 = ( cid:3429 ) 96 ( cid:3433 ) \ud835\udc41 = ( cid:3429 ) 4.8 ( cid:3433 ) . 20 \ud835\udc58\ud835\udc54 \ud835\udc60 ( cid:2870 ) 4 0.2 10\ud835\udc61 \u22122 10\ud835\udc61\u22122 \ud835\udc39 =\ud835\udc39\u20d7 +\ud835\udc39\u20d7 = ( cid:3429 ) \u22123 ( cid:3433 ) \ud835\udc41+ ( cid:3429 ) 11\ud835\udc61 ( cid:2870 ) ( cid:3433 ) \ud835\udc41 = ( cid:3429 ) 11\ud835\udc61 ( cid:2870 ) \u22123 ( cid:3433 ) \ud835\udc41 . ( cid:3041 ) ( cid:3032 ) ( cid:3047 ) ( cid:2869 ) ( cid:2870 ) Note that we will often be able to use F ( cid:4652 ) \u20d7 =\ud835\udc5a\ud835\udc4e\u20d7 , but be 0 4 4 ( cid:2924 ) ( cid:2915 ) ( cid:2930 ) careful that the mass is constant to use the equation ! Example 119 - 2 Momentum and forces A 2.8-kg rock is found to move with a momentum given by First , we can find the net force on the rock , by taking the derivative of the momentum with respect to time as 20 \ud835\udc5d\u20d7= ( cid:3429 ) 10 ( cid:3433 ) \ud835\udc58\ud835\udc54\u2219\ud835\udc5a\u2044\ud835\udc60 . 20 0 \ud835\udc51\ud835\udc5d\u20d7 \ud835\udc51 \ud835\udc58\ud835\udc54\u2219\ud835\udc5a 200\u221227.4\ud835\udc61 F ( cid:4652 ) \u20d7 = = ( cid:3429 ) 10 ( cid:3433 ) = ( cid:3429 ) 0 ( cid:3433 ) \ud835\udc41 . ( cid:2924 ) ( cid:2915 ) ( cid:2930 ) \ud835\udc51\ud835\udc61 \ud835\udc51\ud835\udc61 \ud835\udc60 200\u221227.4\ud835\udc61 \u221227.4 What is the net force acting on the rock and acceleration of the rock due to this net force ? Assuming the mass of the rock is constant , we can then find the acceleration using Solution : F ( cid:4652 ) \u20d7 1 0 0 \ud835\udc5a ( cid:2924 ) ( cid:2915 ) ( cid:2930 ) This problem asks us to use the definition of Newton \u2019 s 2nd law \ud835\udc4e\u20d7 = = ( cid:3429 ) 0 ( cid:3433 ) \ud835\udc41 = ( cid:3429 ) 0 ( cid:3433 ) , \ud835\udc5a 2.8 \ud835\udc58\ud835\udc54 \ud835\udc60 ( cid:2870 ) to find the net force on an object given its known momentum \u221227.4 \u22129.8 ( as a function of time ) . In addition , we will find the acceleration from the information given . which appears to be the acceleration due to gravity . 170",
#         "page": 4
#     },
#     {
#         "unit": "Unit 119",
#         "section": "6 | P h ys i cs",
#         "chunk_type": "paragraph",
#         "content": "= ( cid:2924 ) ( cid:2915 ) ( cid:2930 ) . This problem asks us to find the net force on an object due to ( cid:2924 ) ( cid:2915 ) ( cid:2930 ) \ud835\udc51\ud835\udc61 \ud835\udc5a two individual forces and then to determine the acceleration Therefore , of the object due to those forces . 28 1.4 ( a ) The first step is to use the definition of net force to find 1 \ud835\udc5a \ud835\udc4e\u20d7 = ( cid:3429 ) 96 ( cid:3433 ) \ud835\udc41 = ( cid:3429 ) 4.8 ( cid:3433 ) . 20 \ud835\udc58\ud835\udc54 \ud835\udc60 ( cid:2870 ) 4 0.2 10\ud835\udc61 \u22122 10\ud835\udc61\u22122 \ud835\udc39 =\ud835\udc39\u20d7 +\ud835\udc39\u20d7 = ( cid:3429 ) \u22123 ( cid:3433 ) \ud835\udc41+ ( cid:3429 ) 11\ud835\udc61 ( cid:2870 ) ( cid:3433 ) \ud835\udc41 = ( cid:3429 ) 11\ud835\udc61 ( cid:2870 ) \u22123 ( cid:3433 ) \ud835\udc41 . ( cid:3041 ) ( cid:3032 ) ( cid:3047 ) ( cid:2869 ) ( cid:2870 ) Note that we will often be able to use F ( cid:4652 ) \u20d7 =\ud835\udc5a\ud835\udc4e\u20d7 , but be 0 4 4 ( cid:2924 ) ( cid:2915 ) ( cid:2930 ) careful that the mass is constant to use the equation ! Example 119 - 2 Momentum and forces A 2.8-kg rock is found to move with a momentum given by First , we can find the net force on the rock , by taking the derivative of the momentum with respect to time as 20 \ud835\udc5d\u20d7= ( cid:3429 ) 10 ( cid:3433 ) \ud835\udc58\ud835\udc54\u2219\ud835\udc5a\u2044\ud835\udc60 . 20 0 \ud835\udc51\ud835\udc5d\u20d7 \ud835\udc51 \ud835\udc58\ud835\udc54\u2219\ud835\udc5a 200\u221227.4\ud835\udc61 F ( cid:4652 ) \u20d7 = = ( cid:3429 ) 10 ( cid:3433 ) = ( cid:3429 ) 0 ( cid:3433 ) \ud835\udc41 . ( cid:2924 ) ( cid:2915 ) ( cid:2930 ) \ud835\udc51\ud835\udc61 \ud835\udc51\ud835\udc61 \ud835\udc60 200\u221227.4\ud835\udc61 \u221227.4 What is the net force acting on the rock and acceleration of the rock due to this net force ? Assuming the mass of the rock is constant , we can then find the acceleration using Solution : F ( cid:4652 ) \u20d7 1 0 0 \ud835\udc5a ( cid:2924 ) ( cid:2915 ) ( cid:2930 ) This problem asks us to use the definition of Newton \u2019 s 2nd law \ud835\udc4e\u20d7 = = ( cid:3429 ) 0 ( cid:3433 ) \ud835\udc41 = ( cid:3429 ) 0 ( cid:3433 ) , \ud835\udc5a 2.8 \ud835\udc58\ud835\udc54 \ud835\udc60 ( cid:2870 ) to find the net force on an object given its known momentum \u221227.4 \u22129.8 ( as a function of time ) . In addition , we will find the acceleration from the information given . which appears to be the acceleration due to gravity . 170 Newt on \u2019 s La ws | 119-7",
#         "page": 5
#     },
#     {
#         "unit": "Unit 119",
#         "section": "Free body diagrams",
#         "chunk_type": "paragraph",
#         "content": "Consider : How can we visualize the forces on an object ? When dealing with forces , it is often advisable to make diagram for each object of interest in the system with every force on each object noted . Such a diagram is called a free-body diagram , because we draw each object separate ( free ) and diagram out each force on the diagram . Free-body diagrams are also sometimes called force diagrams . Figure 119-2 shows the free-body diagram of a ball in free fall , i.e . under only the influence of the gravitational force , \ud835\udc39\u20d7 . Some things to note about this diagram ( cid:3034 ) Figure 119-2 . Free- body diagram of a 1 ) The object ( ball ) is represented in a way that it can be identified . ball in free-fall . 2 ) The only force acting on the ball ( gravity ) is identified and drawn as a vector in the direction which it acts . 3 ) No other extraneous information is in the diagram itself . When more than one force acts on an object , each force is drawn on the same diagram . Be sure to include all forces that act on the object , but not any forces caused by the object . Figure 119- 3 shows the free-body diagram for a box sitting on a table such that it undergoes two interactions \u2013 a normal interaction with the table and a gravitational interaction with the earth . Note that the force on the box due to each of these interactions is noted in the free-body diagram . When drawing free-body diagrams , try to follow these rules : Drawing Free-Body Diagrams Figure 119-3 . Free- body diagram of a 1 ) Draw a representative diagram for the object box sitting on a 2 ) Identify all forces that act directly on the object . In physics I , most forces ( except gravity ) table . will be due to direct contact with the object . 3 ) Draw and label an arrow for each force with the direction of the arrow representing the direction of the force . Try to have the tail of each arrow at the place where the force acts on the object . Drawing free-body diagrams correctly can make all the difference for solving force problems . We will see that when writing out Newton \u2019 s 2nd law equations for an object , if you have a correctly formatted free-body diagram , it is simply a matter of converting the forces in the diagram to the equation . In this way , the visual representation of a problem can directly translate to the mathematical representation .",
#         "page": 5
#     },
#     {
#         "unit": "Unit 119",
#         "section": "The gravitational force (near the surface of the earth)",
#         "chunk_type": "paragraph",
#         "content": "Consider : What is the difference between mass and weight ? In Section 3 of Unit 106 , we found that the gravitational field near a large massive object is \ud835\udc3a\ud835\udc5a ( 119-5 ) \ud835\udc54\u20d7=\u2212 \ud835\udc5f\u0302 , \ud835\udc5f ( cid:2870 ) ( cid:2869 ) ( cid:2870 ) ( cid:2869 ) ( cid:2870 ) and we noted that near the surface of the earth , the value of the gravitational field is 9.80 N/kg down . It turns out that the gravitational force on an object of mass , m , is the product of the object \u2019 s mass and the gravitational field in which it is situation . That is \ud835\udc39\u20d7 =\ud835\udc5a\ud835\udc54\u20d7 ( 119-5 ) ( cid:3034 ) The gravitational force on an object is also called its weight . Note that since weight is a force , it has SI units of Newtons ( N ) , or U.S. customary units of points ( lbs . ) . 1 \ud835\udc41 =1 \ud835\udc58\ud835\udc54\u2219\ud835\udc5a\u2044\ud835\udc60 ( cid:2870 ) 1 \ud835\udc41 \u22482.2 \ud835\udc59\ud835\udc4f\ud835\udc60 . ( 119-6 ) 171",
#         "page": 5
#     },
#     {
#         "unit": "Unit 119",
#         "section": "8 | P h ys i cs",
#         "chunk_type": "paragraph",
#         "content": "Consider : What is the difference between mass and weight ? In Section 3 of Unit 106 , we found that the gravitational field near a large massive object is \ud835\udc3a\ud835\udc5a ( 119-5 ) \ud835\udc54\u20d7=\u2212 \ud835\udc5f\u0302 , \ud835\udc5f ( cid:2870 ) ( cid:2869 ) ( cid:2870 ) ( cid:2869 ) ( cid:2870 ) and we noted that near the surface of the earth , the value of the gravitational field is 9.80 N/kg down . It turns out that the gravitational force on an object of mass , m , is the product of the object \u2019 s mass and the gravitational field in which it is situation . That is \ud835\udc39\u20d7 =\ud835\udc5a\ud835\udc54\u20d7 ( 119-5 ) ( cid:3034 ) The gravitational force on an object is also called its weight . Note that since weight is a force , it has SI units of Newtons ( N ) , or U.S. customary units of points ( lbs . ) . 1 \ud835\udc41 =1 \ud835\udc58\ud835\udc54\u2219\ud835\udc5a\u2044\ud835\udc60 ( cid:2870 ) 1 \ud835\udc41 \u22482.2 \ud835\udc59\ud835\udc4f\ud835\udc60 . ( 119-6 ) 171 It is very important to note the difference between mass and weight . Mass is an intrinsic property of an object , that is , it is determined only by the makeup of the object . Weight , on the other hand , depends not only on the mass of the object , but where the object is located in a gravitational field . Let \u2019 s compare an astronaut at the surface of the earth and at the surface of the moon . In Unit 106 , we noted that the gravitational field strength at the surface of the moon is roughly 1/6th the strength of the gravitational field at the surface of the earth . So , for a 70 kg astronaut , we find Body Mass ( \ud835\udc5a ) Weight ( \ud835\udc39 =\ud835\udc5a\ud835\udc54 ) ( cid:3034 ) Earth 70 kg 686 N Moon 70 kg 114 N To summarize : Mass is an intrinsic property of a material and is independent of where the object is in the universe . Weight , on the other hand , is the gravitational force acting on an object and depends on both the mass of the object and the local gravitational field . Gravitational Force ( cid:4652 ) \ud835\udc6d ( cid:4652 ) \u20d7 =\ud835\udc8e\ud835\udc88 ( cid:4652 ) ( cid:4652 ) \u20d7 \ud835\udc88 Description : This equation describes the gravitational force on an object , \ud835\udc39 , as the product of the object \u2019 s mass , \ud835\udc5a , ( cid:3034 ) and the local gravitational field , \ud835\udc54\u20d7 . Note : Near the surface of the earth , the gravitational field strength is often given as 9.80 \ud835\udc5a/\ud835\udc60 ( cid:2870 ) or 9.80 \ud835\udc41/\ud835\udc58\ud835\udc54 For completeness , the gravitational force can be derived from the gravitational potential energy we from Unit 106 , \ud835\udc3a\ud835\udc5a \ud835\udc5a ( cid:2869 ) ( cid:2870 ) \ud835\udc48 =\u2212 . ( 119-7 ) ( cid:3034 ) \ud835\udc5f",
#         "page": 6
#     },
#     {
#         "unit": "Unit 119",
#         "section": "8 | P h ys i cs",
#         "chunk_type": "paragraph",
#         "content": "\ud835\udc5a , ( cid:3034 ) and the local gravitational field , \ud835\udc54\u20d7 . Note : Near the surface of the earth , the gravitational field strength is often given as 9.80 \ud835\udc5a/\ud835\udc60 ( cid:2870 ) or 9.80 \ud835\udc41/\ud835\udc58\ud835\udc54 For completeness , the gravitational force can be derived from the gravitational potential energy we from Unit 106 , \ud835\udc3a\ud835\udc5a \ud835\udc5a ( cid:2869 ) ( cid:2870 ) \ud835\udc48 =\u2212 . ( 119-7 ) ( cid:3034 ) \ud835\udc5f ( cid:2869 ) ( cid:2870 ) We can find the gravitational force using the gradient of this potential energy ( Equation 110-5 ) : \ud835\udc39\u20d7 =\u2212\u2207 ( cid:4652 ) ( cid:4652 ) \u20d7\ud835\udc48 . ( 119-8 ) . Since the gravitational potential energy is written in terms of the radius of a sphere , we must technically take this gradient in spherical-polar coordinates . However , since the radius is the only variable in our potential energy equation , the derivatives with respect to the angular variables ( \ud835\udf03 and \ud835\udf19 ) will be zero . Therefore , we can write \ud835\udf15 \ud835\udc3a\ud835\udc5a \ud835\udc5a \ud835\udc3a\ud835\udc5a \ud835\udc5a \ud835\udc39\u20d7 =\u2212\u2207 ( cid:4652 ) ( cid:4652 ) \u20d7\ud835\udc48 =\u2212 ( cid:3436 ) \u2212 ( cid:2869 ) ( cid:2870 ) ( cid:3440 ) \ud835\udc5f\u0302 =\u2212 ( cid:2869 ) ( cid:2870 ) \ud835\udc5f\u0302 . ( 119-9 ) ( cid:3034 ) ( cid:3034 ) \ud835\udf15\ud835\udc5f \ud835\udc5f \ud835\udc5f ( cid:2870 ) ( cid:2869 ) ( cid:2870 ) ( cid:2869 ) ( cid:2870 ) Equation 119-8 is called Newton \u2019 s Universal Law of Gravity , and can be used to determine the gravitational force between any two massive bodies , whether that be a person standing at the earth \u2019 s surface , or a planet orbiting a star . We will return to this general equation in Unit 128 . For now , we can rewrite equation 119-8 as \ud835\udc3a\ud835\udc5a \ud835\udc39\u20d7 =\u2212 ( cid:4678 ) ( cid:2869 ) ( cid:4679 ) \ud835\udc5a \ud835\udc5f\u0302 , ( 119-10 ) ( cid:3034 ) \ud835\udc5f ( cid:2870 ) ( cid:2870 ) ( cid:2869 ) ( cid:2870 ) and use the definition of the gravitational field ( Equation 119-5 ) to simplify this to \ud835\udc39\u20d7 =\ud835\udc5a\ud835\udc54\u20d7 , ( 119-11 ) ( cid:3034 ) which is the relationship for the gravitational force near the surface of the earth we were looking for . 172",
#         "page": 6
#     },
#     {
#         "unit": "Unit 119",
#         "section": "8 | P h ys i cs",
#         "chunk_type": "paragraph",
#         "content": "\ud835\udc5a , ( cid:3034 ) and the local gravitational field , \ud835\udc54\u20d7 . Note : Near the surface of the earth , the gravitational field strength is often given as 9.80 \ud835\udc5a/\ud835\udc60 ( cid:2870 ) or 9.80 \ud835\udc41/\ud835\udc58\ud835\udc54 For completeness , the gravitational force can be derived from the gravitational potential energy we from Unit 106 , \ud835\udc3a\ud835\udc5a \ud835\udc5a ( cid:2869 ) ( cid:2870 ) \ud835\udc48 =\u2212 . ( 119-7 ) ( cid:3034 ) \ud835\udc5f ( cid:2869 ) ( cid:2870 ) We can find the gravitational force using the gradient of this potential energy ( Equation 110-5 ) : \ud835\udc39\u20d7 =\u2212\u2207 ( cid:4652 ) ( cid:4652 ) \u20d7\ud835\udc48 . ( 119-8 ) . Since the gravitational potential energy is written in terms of the radius of a sphere , we must technically take this gradient in spherical-polar coordinates . However , since the radius is the only variable in our potential energy equation , the derivatives with respect to the angular variables ( \ud835\udf03 and \ud835\udf19 ) will be zero . Therefore , we can write \ud835\udf15 \ud835\udc3a\ud835\udc5a \ud835\udc5a \ud835\udc3a\ud835\udc5a \ud835\udc5a \ud835\udc39\u20d7 =\u2212\u2207 ( cid:4652 ) ( cid:4652 ) \u20d7\ud835\udc48 =\u2212 ( cid:3436 ) \u2212 ( cid:2869 ) ( cid:2870 ) ( cid:3440 ) \ud835\udc5f\u0302 =\u2212 ( cid:2869 ) ( cid:2870 ) \ud835\udc5f\u0302 . ( 119-9 ) ( cid:3034 ) ( cid:3034 ) \ud835\udf15\ud835\udc5f \ud835\udc5f \ud835\udc5f ( cid:2870 ) ( cid:2869 ) ( cid:2870 ) ( cid:2869 ) ( cid:2870 ) Equation 119-8 is called Newton \u2019 s Universal Law of Gravity , and can be used to determine the gravitational force between any two massive bodies , whether that be a person standing at the earth \u2019 s surface , or a planet orbiting a star . We will return to this general equation in Unit 128 . For now , we can rewrite equation 119-8 as \ud835\udc3a\ud835\udc5a \ud835\udc39\u20d7 =\u2212 ( cid:4678 ) ( cid:2869 ) ( cid:4679 ) \ud835\udc5a \ud835\udc5f\u0302 , ( 119-10 ) ( cid:3034 ) \ud835\udc5f ( cid:2870 ) ( cid:2870 ) ( cid:2869 ) ( cid:2870 ) and use the definition of the gravitational field ( Equation 119-5 ) to simplify this to \ud835\udc39\u20d7 =\ud835\udc5a\ud835\udc54\u20d7 , ( 119-11 ) ( cid:3034 ) which is the relationship for the gravitational force near the surface of the earth we were looking for . 172 Newt on \u2019 s La ws | 119-9 Example 119 - 3 Being careful with weight . A U.S. penny has a mass of 3.1 grams . What is the weight of 0 \ud835\udc5a 0 this penny at the surface of the earth ? \ud835\udc39\u20d7 ( cid:3034 ) =\ud835\udc5a\ud835\udc54\u20d7 =0.0031\ud835\udc58\ud835\udc54 ( cid:3429 ) 0 ( cid:3433 ) \ud835\udc60 ( cid:2870 ) = ( cid:3429 ) 0 ( cid:3433 ) \ud835\udc41 . \u22129.8 \u22120.030 Solution : A few things to note : This is a direct application for the relationship between the 1 ) The weight , as force , is a vector . We can often",
#         "page": 7
#     },
#     {
#         "unit": "Unit 119",
#         "section": "8 | P h ys i cs",
#         "chunk_type": "paragraph",
#         "content": "of 0 \ud835\udc5a 0 this penny at the surface of the earth ? \ud835\udc39\u20d7 ( cid:3034 ) =\ud835\udc5a\ud835\udc54\u20d7 =0.0031\ud835\udc58\ud835\udc54 ( cid:3429 ) 0 ( cid:3433 ) \ud835\udc60 ( cid:2870 ) = ( cid:3429 ) 0 ( cid:3433 ) \ud835\udc41 . \u22129.8 \u22120.030 Solution : A few things to note : This is a direct application for the relationship between the 1 ) The weight , as force , is a vector . We can often mass of an object and its weight ( the gravitational force on the denote this by saying the weight is 0.030 N object ) . down . 2 ) The magnitude of the gravitational field strength For this problem , I will take vertically up as the positive ( \ud835\udc54 ) is positive . The negative in the above direction for the z-axis . Since we know the mass is 3.1 grams equation comes from the direction of the ( 0.0031 kg ) , we can directly find the weight as gravitational field . Example 119 - 4 Moon rock A moon rock brought back to earth during an Apollo mission to find it for the rock at both surfaces . Therefore , for the has a mass of 0.61 kg . What are the mass and weight of this earth we find rock when it was on the moon and now that it is on earth ? 0 \ud835\udc5a 0 Solution : \ud835\udc39\u20d7 ( cid:3034 ) =0.61\ud835\udc58\ud835\udc54 ( cid:3429 ) 0 ( cid:3433 ) \ud835\udc60 ( cid:2870 ) = ( cid:3429 ) 0 ( cid:3433 ) \ud835\udc41 \u22129.8 \u22126.0 This problem asks us to compare the mass and weight of an object on the earth and the moon . In order to do this , we will and for the moon we find use the definition of weight given in the unit . 0 0 \ud835\udc5a \ud835\udc39\u20d7 =0.61\ud835\udc58\ud835\udc54 ( cid:3429 ) 0 ( cid:3433 ) = ( cid:3429 ) 0 ( cid:3433 ) \ud835\udc41 , First , it is important to realize that as an intrinsic property , the ( cid:3034 ) \ud835\udc60 ( cid:2870 ) \u22121.6 \u22120.98 mass of the moon rock is the same everywhere \u2013 so it is certainly the same at the surface of the moon and the surface where I have used the gravitational field strength for the of the earth . moon given early in this unit . As for the weight , we can use the definition , Again , note the vector nature of weight . As we become more familiar with such problems , it will become easy to \ud835\udc39\u20d7 =\ud835\udc5a\ud835\udc54\u20d7 , ( cid:3034 ) forget that weight is a vector \u2013 which can lead to mistakes .",
#         "page": 7
#     },
#     {
#         "unit": "Unit 119",
#         "section": "Newton\u2019s third law",
#         "chunk_type": "paragraph",
#         "content": "Consider : Why is it that for every force there is an equal and opposite force ? Growing up , you have probably heard the phrase \u201c for every action there is an equal and opposite reaction. \u201d This is a statement of Newton \u2019 s 3rd law ; however , we have to be very careful about how we apply this law . First , Newton \u2019 s 3rd law is concerned with forces , so we could reword the colloquial saying above as \u2018 every force has an equal and opposite force . \u201d Now , we have to be careful , because if every force has an exact opposite partner , how is possible that any object ever accelerates ? That is , if every force has an opposite pair , shouldn \u2019 t those pairs , coupled with Newton \u2019 s 2nd law , tell us that the net force on an object is always zero ? The subtlety that resolves this situation is that the equal and opposite forces spoken of in Newton \u2019 s 3rd law must act on different objects . Remember that a single force on an object is the result of the object \u2019 s interaction with another object . For example , the gravitational force acting on you right now is the result of the interaction between you and the earth . The third law pair , as they are called of the gravitational force of the earth on you , must lie at the other end of that interaction \u2013 the gravitational force of you on the earth . This is how we can have equal and opposite forces , but yet have some form of net acceleration . There is a simple turn of phrase you can use to ensure that you are finding the correct third law partner to a force : 173",
#         "page": 7
#     },
#     {
#         "unit": "Unit 119",
#         "section": "10 | P h ys i cs",
#         "chunk_type": "paragraph",
#         "content": "Consider : Why is it that for every force there is an equal and opposite force ? Growing up , you have probably heard the phrase \u201c for every action there is an equal and opposite reaction. \u201d This is a statement of Newton \u2019 s 3rd law ; however , we have to be very careful about how we apply this law . First , Newton \u2019 s 3rd law is concerned with forces , so we could reword the colloquial saying above as \u2018 every force has an equal and opposite force . \u201d Now , we have to be careful , because if every force has an exact opposite partner , how is possible that any object ever accelerates ? That is , if every force has an opposite pair , shouldn \u2019 t those pairs , coupled with Newton \u2019 s 2nd law , tell us that the net force on an object is always zero ? The subtlety that resolves this situation is that the equal and opposite forces spoken of in Newton \u2019 s 3rd law must act on different objects . Remember that a single force on an object is the result of the object \u2019 s interaction with another object . For example , the gravitational force acting on you right now is the result of the interaction between you and the earth . The third law pair , as they are called of the gravitational force of the earth on you , must lie at the other end of that interaction \u2013 the gravitational force of you on the earth . This is how we can have equal and opposite forces , but yet have some form of net acceleration . There is a simple turn of phrase you can use to ensure that you are finding the correct third law partner to a force : 173 For two interacting objects ( object 1 and object 2 ) : Given a force on object 1 caused by object 2 in a given direction , the 3rd law pair is A force of the same type on object 2 by object 1 in the opposite direction . Above , I used the example of the gravitational force of the earth on you . The 3rd law statement for this situation would be For the gravitational force on you by the earth directed towards the center of the earth , the third law pair is A gravitational force on the earth by you directed towards the center of you . Note that this statement has the same type of force and the object causing the force and acted on by the force are reversed , as are the directions . Now , consider a box sitting on a flat table ( see Figure 119-3 ) . There are two forces acting on the box , the",
#         "page": 8
#     },
#     {
#         "unit": "Unit 119",
#         "section": "10 | P h ys i cs",
#         "chunk_type": "paragraph",
#         "content": "third law pair is A gravitational force on the earth by you directed towards the center of you . Note that this statement has the same type of force and the object causing the force and acted on by the force are reversed , as are the directions . Now , consider a box sitting on a flat table ( see Figure 119-3 ) . There are two forces acting on the box , the gravitational force of the earth on the box ( downward ) and the normal force of the table on the box ( upward ) . Note : The normal force is not the 3rd law pair of the gravitational force . As we just saw above , the 3rd law pair of the gravitational force on the box by the earth is a gravitational force of the box on the earth . What about the normal force ? Using our sentence pairs , we have For the normal force on the box by the table directed up , the third law pair is A normal force of the box on the table directed down . The box pushes down on the table just as much as the table pushes up on the box . A few notes about third law pairs 1 ) Third law pairs will never be in the same free body diagram since they act on different objects . 2 ) If you have a problem with multiple interacting objects , it \u2019 s often good to note third law pairs in some way ( subscripts ) . For example , if box 1 pushes on box 2 with a force of magnitude F , the in the other free body 21 diagram you may want to call the force of box 2 on box 1 F . This is tantamount to eliminating one unknown , since 12 you know those forces have the same magnitude and opposite direction . Example 119 - 5 A hanging mass For the 100 N mass below , identify the forces acting on the where \ud835\udc47 is the tension force of the string on the box and box and state the third law pair for each force . \ud835\udc5a\ud835\udc54 is the gravitational force of the earth on the box ( note that we do not require calling this force , \ud835\udc39 , it is just ( cid:3034 ) important to be consistent ) . To find the third law pair for each of these forces , we put together our sentences : There is a tension force of the string on the box upward , Solution : the third law pair is This problem asks us to determine forces on a box as well as A tension force of the box on the string downward . the third law pair for each force . In order to do this , we first",
#         "page": 8
#     },
#     {
#         "unit": "Unit 119",
#         "section": "10 | P h ys i cs",
#         "chunk_type": "paragraph",
#         "content": "third law pair for each of these forces , we put together our sentences : There is a tension force of the string on the box upward , Solution : the third law pair is This problem asks us to determine forces on a box as well as A tension force of the box on the string downward . the third law pair for each force . In order to do this , we first show the free body diagram for the mass as There is a gravitational force of the earth on the box downward , the third law pair is A gravitational force of the box on the earth upward . Again , note that the third law pairs do not show up in our free body diagram because they act on different bodies than the one if the diagram . 174",
#         "page": 8
#     }
# ]
