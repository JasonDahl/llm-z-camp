# %%
# Enable autoreload of imported modules
# %load_ext autoreload
# %autoreload 2
import sys
import os
# Add parent of 'physbot' to the path
sys.path.append(os.path.abspath(".."))
    
import json
import logging
from tqdm import tqdm
from pathlib import Path
from elasticsearch import Elasticsearch
from openai import OpenAI
from dotenv import load_dotenv
from physbot.path_utils import get_project_root
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load environment variables from the project root
# For Jupyter: assume this notebook is in /PhysBot/notebooks
notebook_dir = Path.cwd()
project_root = get_project_root()
load_dotenv(dotenv_path=project_root / ".env")

# OpenAI API Key
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# Elasticsearch settings
ES_HOST = "http://localhost:9200"
ES_INDEX = "physbot_units"

# Paths
JSON_DIR = project_root / "data" / "json"

# %%
# Configure logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s [%(levelname)s] %(message)s")

# Initialize Elasticsearch and OpenAI clients
es = Elasticsearch(ES_HOST)
openai_client = OpenAI(api_key=OPENAI_API_KEY)

# %%
def create_physbot_index(es_client: Elasticsearch, index_name: str = "physbot_units"):
    """
    Creates an Elasticsearch index for PhysBot with OpenAI-compatible embedding and rich metadata.
    """
    index_body = {
        "settings": {
            "number_of_shards": 1,
            "number_of_replicas": 0
        },
        "mappings": {
            "properties": {
                "unit": {"type": "keyword"},
                "section": {"type": "keyword"},
                "content": {"type": "text"},
                "embedding": {
                    "type": "dense_vector",
                    "dims": 1536,
                    "index": True,
                    "similarity": "cosine"
                },
                "source": {"type": "keyword"},
                "chunk_index": {"type": "integer"}
            }
        }
    }

    # Delete old index if it exists
    if es_client.indices.exists(index=index_name):
        print(f"🗑️ Deleting existing index '{index_name}'...")
        es_client.indices.delete(index=index_name)
        print("✅ Deleted.")
    
    # Create fresh index with correct settings
    print(f"🆕 Creating index '{index_name}'...")
    es_client.indices.create(index=index_name, body=index_body)
    print("✅ Index created successfully.")

def embed_text(text):
    """Get a 1536-dim OpenAI embedding for the given text with validation."""
    response = openai_client.embeddings.create(
        model="text-embedding-ada-002",
        input=text
    )
    embedding = response.data[0].embedding

    # Validation
    if not isinstance(embedding, list) or not all(isinstance(x, (float, int)) for x in embedding):
        raise ValueError("Embedding is not a flat list of floats.")
    if len(embedding) != 1536:
        raise ValueError(f"Expected 1536-dim embedding, got {len(embedding)}.")

    return embedding

def validate_doc(doc):
    # Check embedding format
    embedding = doc.get("embedding", [])
    if not isinstance(embedding, list):
        raise ValueError("Embedding must be a list.")
    if len(embedding) != 1536:
        raise ValueError(f"Embedding must be 1536 dimensions, got {len(embedding)}")
    if not all(isinstance(x, (float, int)) for x in embedding):
        raise ValueError("Embedding contains non-numeric values.")

    # Check required fields
    for key in ["unit", "section", "content", "source", "chunk_index"]:
        if key not in doc:
            raise ValueError(f"Missing required field: {key}")
        if key in ["unit", "section", "content", "source"] and not isinstance(doc[key], str):
            raise ValueError(f"Field {key} must be a string.")
        if key == "chunk_index" and not isinstance(doc[key], int):
            raise ValueError("chunk_index must be an integer.")

    return True

def index_unit_file(json_path):
    """Index all text chunks from a single unit JSON file."""
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    unit = data.get("unit", "Unknown")
    text_chunks = data.get("text_chunks", [])

    for i, chunk in enumerate(tqdm(text_chunks, desc=f"Indexing {json_path.name}")):
        content = chunk.get("content", "").strip()
        if not content:
            continue

        try:
            embedding = embed_text(content)
        except Exception as e:
            logging.error(f"❌ Embedding failed for chunk {i} in {json_path.name}: {str(e)}")
            continue

        doc = {
            "unit": unit,
            "section": chunk.get("section", "Unknown"),
            "content": content,
            "embedding": embedding,
            "source": json_path.name,
            "chunk_index": i
        }

        try:
            validate_doc(doc)
            es.index(index=ES_INDEX, document=doc)
        except Exception as validation_error:
            logging.error(f"❌ Failed to index chunk {i} from {json_path.name}: {validation_error}")

# %%
create_physbot_index(es)
# Out:
# 2025-05-04 12:46:55,377 [INFO] HEAD http://localhost:9200/physbot_units [status:200 duration:0.013s]
# 2025-05-04 12:46:55,471 [INFO] DELETE http://localhost:9200/physbot_units [status:200 duration:0.092s]
# /tmp/ipykernel_24838/1067547493.py:35: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   es_client.indices.create(index=index_name, body=index_body)
# 🗑️ Deleting existing index 'physbot_units'...
# ✅ Deleted.
# 🆕 Creating index 'physbot_units'...
# 2025-05-04 12:46:55,757 [INFO] PUT http://localhost:9200/physbot_units [status:200 duration:0.256s]
# ✅ Index created successfully.

# %%
json_files = sorted(JSON_DIR.glob("unit_*.json"))
for json_file in json_files:
    try:
        index_unit_file(json_file)
    except Exception as e:
        logging.error(f"❌ Failed to index {json_file.name}: {str(e)}")
# Out:
# Indexing unit_101_output.json:   0%|                                                      | 0/19 [00:00<?, ?it/s]2025-05-04 12:47:20,246 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:20,273 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.021s]
# Indexing unit_101_output.json:   5%|██▍                                           | 1/19 [00:00<00:10,  1.74it/s]2025-05-04 12:47:20,693 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:20,716 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.017s]
# Indexing unit_101_output.json:  11%|████▊                                         | 2/19 [00:01<00:08,  2.01it/s]2025-05-04 12:47:21,049 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:21,075 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.020s]
# Indexing unit_101_output.json:  16%|███████▎                                      | 3/19 [00:01<00:06,  2.30it/s]2025-05-04 12:47:21,512 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:21,538 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.018s]
# Indexing unit_101_output.json:  21%|█████████▋                                    | 4/19 [00:01<00:06,  2.24it/s]2025-05-04 12:47:21,836 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:21,858 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.018s]
# Indexing unit_101_output.json:  26%|████████████                                  | 5/19 [00:02<00:05,  2.50it/s]2025-05-04 12:47:22,283 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:22,304 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.016s]
# Indexing unit_101_output.json:  32%|██████████████▌                               | 6/19 [00:02<00:05,  2.41it/s]2025-05-04 12:47:22,605 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:22,633 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.022s]
# Indexing unit_101_output.json:  37%|████████████████▉                             | 7/19 [00:02<00:04,  2.58it/s]2025-05-04 12:47:20,377 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:20,416 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.018s]
# 2025-05-04 12:47:20,769 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:20,791 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.018s]
# 2025-05-04 12:47:21,116 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:21,143 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.020s]
# 2025-05-04 12:47:21,450 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:21,475 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.020s]
# 2025-05-04 12:47:21,836 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:21,859 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.018s]
# 2025-05-04 12:47:22,204 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:22,226 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.017s]
# 2025-05-04 12:47:22,568 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:22,589 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.017s]
# 2025-05-04 12:47:23,011 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:23,034 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.018s]
# Indexing unit_101_output.json:  79%|███████████████████████████████████▌         | 15/19 [00:03<00:00,  8.24it/s]2025-05-04 12:47:23,349 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:23,383 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.026s]
# Indexing unit_101_output.json:  84%|█████████████████████████████████████▉       | 16/19 [00:03<00:00,  6.69it/s]2025-05-04 12:47:23,749 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:23,769 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.016s]
# Indexing unit_101_output.json:  89%|████████████████████████████████████████▎    | 17/19 [00:04<00:00,  5.41it/s]2025-05-04 12:47:23,990 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:24,010 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.015s]
# Indexing unit_101_output.json:  95%|██████████████████████████████████████████▋  | 18/19 [00:04<00:00,  5.13it/s]2025-05-04 12:47:24,365 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:24,440 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.071s]
# Indexing unit_101_output.json: 100%|█████████████████████████████████████████████| 19/19 [00:04<00:00,  4.01it/s]
# Indexing unit_102_output.json:   0%|                                                      | 0/17 [00:00<?, ?it/s]2025-05-04 12:47:24,853 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:24,879 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.020s]
# Indexing unit_102_output.json:   6%|██▋                                           | 1/17 [00:00<00:06,  2.37it/s]2025-05-04 12:47:25,284 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:25,341 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.052s]
# Indexing unit_102_output.json:  12%|█████▍                                        | 2/17 [00:00<00:06,  2.25it/s]2025-05-04 12:47:25,679 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:25,702 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.018s]
# Indexing unit_102_output.json:  18%|████████                                      | 3/17 [00:01<00:05,  2.46it/s]2025-05-04 12:47:26,109 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:26,131 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.017s]
# Indexing unit_102_output.json:  24%|██████████▊                                   | 4/17 [00:01<00:05,  2.41it/s]2025-05-04 12:47:26,537 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:26,559 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.018s]
# Indexing unit_102_output.json:  29%|█████████████▌                                | 5/17 [00:02<00:05,  2.38it/s]2025-05-04 12:47:26,901 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:26,925 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.019s]
# Indexing unit_102_output.json:  35%|████████████████▏                             | 6/17 [00:02<00:04,  2.49it/s]2025-05-04 12:47:27,230 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:27,417 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.182s]
# Indexing unit_102_output.json:  41%|██████████████████▉                           | 7/17 [00:02<00:04,  2.32it/s]2025-05-04 12:47:27,715 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:27,738 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.016s]
# Indexing unit_102_output.json:  47%|█████████████████████▋                        | 8/17 [00:03<00:03,  2.53it/s]2025-05-04 12:47:28,002 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:28,023 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.018s]
# Indexing unit_102_output.json:  53%|████████████████████████▎                     | 9/17 [00:03<00:02,  2.77it/s]2025-05-04 12:47:28,399 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:28,421 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.016s]
# Indexing unit_102_output.json:  59%|██████████████████████████▍                  | 10/17 [00:03<00:02,  2.68it/s]2025-05-04 12:47:28,810 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:28,831 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.016s]
# Indexing unit_102_output.json:  65%|█████████████████████████████                | 11/17 [00:04<00:02,  2.60it/s]2025-05-04 12:47:29,112 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:29,133 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.017s]
# Indexing unit_102_output.json:  71%|███████████████████████████████▊             | 12/17 [00:04<00:01,  2.78it/s]2025-05-04 12:47:29,480 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:29,500 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.015s]
# Indexing unit_102_output.json:  76%|██████████████████████████████████▍          | 13/17 [00:05<00:01,  2.76it/s]2025-05-04 12:47:29,942 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:29,960 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.015s]
# Indexing unit_102_output.json:  82%|█████████████████████████████████████        | 14/17 [00:05<00:01,  2.56it/s]2025-05-04 12:47:30,327 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:30,349 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.018s]
# Indexing unit_102_output.json:  88%|███████████████████████████████████████▋     | 15/17 [00:05<00:00,  2.56it/s]2025-05-04 12:47:30,790 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:30,810 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.015s]
# Indexing unit_102_output.json:  94%|██████████████████████████████████████████▎  | 16/17 [00:06<00:00,  2.43it/s]2025-05-04 12:47:31,169 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47:31,190 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.016s]
# Indexing unit_102_output.json: 100%|█████████████████████████████████████████████| 17/17 [00:06<00:00,  2.52it/s]
# Indexing unit_103_output.json:   0%|                                                      | 0/16 [00:00<?, ?it/s]2025-05-04 12:47:31,614 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:47
[INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.014s]
# Indexing unit_131_output.json:  33%|███████████████▎                              | 4/12 [00:01<00:03,  2.29it/s]2025-05-04 12:49:55,667 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:49:55,686 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.014s]
# Indexing unit_131_output.json:  42%|███████████████████▏                          | 5/12 [00:02<00:03,  2.17it/s]2025-05-04 12:49:56,181 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:49:56,202 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.015s]
# Indexing unit_131_output.json:  50%|███████████████████████                       | 6/12 [00:02<00:02,  2.09it/s]2025-05-04 12:49:56,652 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:49:56,670 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.013s]
# Indexing unit_131_output.json:  58%|██████████████████████████▊                   | 7/12 [00:03<00:02,  2.10it/s]2025-05-04 12:49:57,328 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:49:57,348 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.015s]
# Indexing unit_131_output.json:  67%|██████████████████████████████▋               | 8/12 [00:03<00:02,  1.85it/s]2025-05-04 12:49:57,869 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:49:57,887 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.013s]
# Indexing unit_131_output.json:  75%|██████████████████████████████████▌           | 9/12 [00:04<00:01,  1.85it/s]2025-05-04 12:49:58,110 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:49:58,127 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.013s]
# Indexing unit_131_output.json:  83%|█████████████████████████████████████▌       | 10/12 [00:04<00:00,  2.24it/s]2025-05-04 12:49:58,716 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:49:58,739 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.016s]
# Indexing unit_131_output.json:  92%|█████████████████████████████████████████▎   | 11/12 [00:05<00:00,  2.01it/s]2025-05-04 12:49:59,458 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:49:59,476 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.013s]
# Indexing unit_131_output.json: 100%|█████████████████████████████████████████████| 12/12 [00:06<00:00,  1.98it/s]
# Indexing unit_132_output.json:   0%|                                                       | 0/7 [00:00<?, ?it/s]2025-05-04 12:50:01,109 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:01,125 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.012s]
# Indexing unit_132_output.json:  14%|██████▋                                        | 1/7 [00:01<00:09,  1.64s/it]2025-05-04 12:50:01,882 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:01,900 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.013s]
# Indexing unit_132_output.json:  29%|█████████████▍                                 | 2/7 [00:02<00:05,  1.13s/it]2025-05-04 12:50:02,360 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:02,377 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.012s]
# Indexing unit_132_output.json:  43%|████████████████████▏                          | 3/7 [00:02<00:03,  1.20it/s]2025-05-04 12:50:02,655 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:02,672 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.012s]
# Indexing unit_132_output.json:  57%|██████████████████████████▊                    | 4/7 [00:03<00:01,  1.61it/s]2025-05-04 12:50:03,100 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:03,120 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.014s]
# Indexing unit_132_output.json:  71%|█████████████████████████████████▌             | 5/7 [00:03<00:01,  1.79it/s]2025-05-04 12:50:03,505 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:03,524 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.014s]
# Indexing unit_132_output.json:  86%|████████████████████████████████████████▎      | 6/7 [00:04<00:00,  1.98it/s]2025-05-04 12:50:04,091 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:04,112 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.016s]
# Indexing unit_132_output.json: 100%|███████████████████████████████████████████████| 7/7 [00:04<00:00,  1.51it/s]
# Indexing unit_133_output.json:   0%|                                                      | 0/10 [00:00<?, ?it/s]2025-05-04 12:50:04,933 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:04,954 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.017s]
# Indexing unit_133_output.json:  10%|████▌                                         | 1/10 [00:00<00:07,  1.20it/s]2025-05-04 12:50:05,320 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:05,339 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.013s]
# Indexing unit_133_output.json:  20%|█████████▏                                    | 2/10 [00:01<00:04,  1.75it/s]2025-05-04 12:50:05,814 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:05,863 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.043s]
# Indexing unit_133_output.json:  30%|█████████████▊                                | 3/10 [00:01<00:03,  1.82it/s]2025-05-04 12:50:04,178 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:04,198 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.015s]
# 2025-05-04 12:50:04,893 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:04,908 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.012s]
# 2025-05-04 12:50:05,530 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:05,547 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.013s]
# 2025-05-04 12:50:06,283 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:06,303 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.016s]
# Indexing unit_133_output.json:  70%|████████████████████████████████▏             | 7/10 [00:02<00:00,  4.32it/s]2025-05-04 12:50:07,226 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:07,243 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.013s]
# Indexing unit_133_output.json:  80%|████████████████████████████████████▊         | 8/10 [00:03<00:00,  2.65it/s]2025-05-04 12:50:08,155 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:08,171 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.012s]
# Indexing unit_133_output.json:  90%|█████████████████████████████████████████▍    | 9/10 [00:04<00:00,  1.99it/s]2025-05-04 12:50:08,697 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:08,714 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.013s]
# Indexing unit_133_output.json: 100%|█████████████████████████████████████████████| 10/10 [00:04<00:00,  2.18it/s]
# Indexing unit_APP1_output.json:   0%|                                                     | 0/12 [00:00<?, ?it/s]2025-05-04 12:50:08,977 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:08,992 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.012s]
# Indexing unit_APP1_output.json:   8%|███▊                                         | 1/12 [00:00<00:03,  3.66it/s]2025-05-04 12:50:09,431 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:09,652 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.214s]
# Indexing unit_APP1_output.json:  17%|███████▌                                     | 2/12 [00:00<00:05,  2.00it/s]2025-05-04 12:50:09,867 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:09,916 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.042s]
# Indexing unit_APP1_output.json:  25%|███████████▎                                 | 3/12 [00:01<00:03,  2.54it/s]2025-05-04 12:50:10,251 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:10,269 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.013s]
# Indexing unit_APP1_output.json:  33%|███████████████                              | 4/12 [00:01<00:03,  2.65it/s]2025-05-04 12:50:10,562 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:10,579 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.012s]
# Indexing unit_APP1_output.json:  42%|██████████████████▊                          | 5/12 [00:01<00:02,  2.84it/s]2025-05-04 12:50:11,033 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:11,050 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.013s]
# Indexing unit_APP1_output.json:  50%|██████████████████████▌                      | 6/12 [00:02<00:02,  2.55it/s]2025-05-04 12:50:11,437 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:11,454 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.013s]
# Indexing unit_APP1_output.json:  58%|██████████████████████████▎                  | 7/12 [00:02<00:01,  2.52it/s]2025-05-04 12:50:11,773 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:11,790 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.012s]
# Indexing unit_APP1_output.json:  67%|██████████████████████████████               | 8/12 [00:03<00:01,  2.65it/s]2025-05-04 12:50:12,100 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:12,119 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.014s]
# Indexing unit_APP1_output.json:  75%|█████████████████████████████████▊           | 9/12 [00:03<00:01,  2.76it/s]2025-05-04 12:50:12,366 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:12,406 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.033s]
# Indexing unit_APP1_output.json:  83%|████████████████████████████████████▋       | 10/12 [00:03<00:00,  2.95it/s]2025-05-04 12:50:12,801 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:12,817 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.012s]
# Indexing unit_APP1_output.json:  92%|████████████████████████████████████████▎   | 11/12 [00:04<00:00,  2.77it/s]2025-05-04 12:50:13,213 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:13,231 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.014s]
# Indexing unit_APP1_output.json: 100%|████████████████████████████████████████████| 12/12 [00:04<00:00,  2.66it/s]
# Indexing unit_APP2_output.json:   0%|                                                      | 0/8 [00:00<?, ?it/s]2025-05-04 12:50:13,619 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:13,635 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.013s]
# Indexing unit_APP2_output.json:  12%|█████▊                                        | 1/8 [00:00<00:02,  2.50it/s]2025-05-04 12:50:14,071 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:14,094 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.016s]
# Indexing unit_APP2_output.json:  25%|███████████▌                                  | 2/8 [00:00<00:02,  2.30it/s]2025-05-04 12:50:14,888 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:14,906 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.014s]
# Indexing unit_APP2_output.json:  38%|█████████████████▎                            | 3/8 [00:01<00:03,  1.65it/s]2025-05-04 12:50:15,557 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:15,573 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.012s]
# Indexing unit_APP2_output.json:  50%|███████████████████████                       | 4/8 [00:02<00:02,  1.59it/s]2025-05-04 12:50:16,100 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:16,115 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.011s]
# Indexing unit_APP2_output.json:  62%|████████████████████████████▊                 | 5/8 [00:02<00:01,  1.67it/s]2025-05-04 12:50:16,883 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:16,904 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.015s]
# Indexing unit_APP2_output.json:  75%|██████████████████████████████████▌           | 6/8 [00:03<00:01,  1.51it/s]2025-05-04 12:50:17,647 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:17,663 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.012s]
# Indexing unit_APP2_output.json:  88%|████████████████████████████████████████▎     | 7/8 [00:04<00:00,  1.44it/s]2025-05-04 12:50:17,981 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:17,996 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.011s]
# Indexing unit_APP2_output.json: 100%|██████████████████████████████████████████████| 8/8 [00:04<00:00,  1.68it/s]
# Indexing unit_APP3_output.json: 0it [00:00, ?it/s]
# Indexing unit_z2_output.json:   0%|                                                        | 0/2 [00:00<?, ?it/s]2025-05-04 12:50:18,422 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:18,439 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.014s]
# Indexing unit_z2_output.json:  50%|████████████████████████                        | 1/2 [00:00<00:00,  2.31it/s]2025-05-04 12:50:19,248 [INFO] HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-05-04 12:50:19,267 [INFO] POST http://localhost:9200/physbot_units/_doc [status:201 duration:0.015s]
# Indexing unit_z2_output.json: 100%|████████████████████████████████████████████████| 2/2 [00:01<00:00,  1.58it/s]

# %%
from collections import defaultdict

# Aggregation query to count docs grouped by 'source' (e.g., unit_101_output.json)
query = {
    "size": 0,
    "aggs": {
        "by_source": {
            "terms": {
                "field": "source",
                "size": 1000  # Adjust as needed if you have many files
            }
        }
    }
}

response = es.search(index=ES_INDEX, body=query)
buckets = response.get("aggregations", {}).get("by_source", {}).get("buckets", [])

print("\n📊 Document Count per Unit File:\n")
for bucket in sorted(buckets, key=lambda b: b["key"]):
    print(f"{bucket['key']:<30} → {bucket['doc_count']} chunks")
# Out:
# /tmp/ipykernel_24838/3863580951.py:16: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   response = es.search(index=ES_INDEX, body=query)
# 2025-05-04 13:24:29,269 [INFO] POST http://localhost:9200/physbot_units/_search [status:200 duration:0.305s]
# 📊 Document Count per Unit File:
#
# unit_101_output.json           → 19 chunks
# unit_102_output.json           → 17 chunks
# unit_103_output.json           → 16 chunks
# unit_104_output.json           → 12 chunks
# unit_105_output.json           → 19 chunks
# unit_106_output.json           → 13 chunks
# unit_107_output.json           → 12 chunks
# unit_108_output.json           → 17 chunks
# unit_109_output.json           → 16 chunks
# unit_110_output.json           → 18 chunks
# unit_111_output.json           → 8 chunks
# unit_112_output.json           → 17 chunks
# unit_113_output.json           → 7 chunks
# unit_114_output.json           → 12 chunks
# unit_115_output.json           → 10 chunks
# unit_116_output.json           → 9 chunks
# unit_117_output.json           → 10 chunks
# unit_118_output.json           → 8 chunks
# unit_119_output.json           → 13 chunks
# unit_120_output.json           → 14 chunks
# unit_121_output.json           → 8 chunks
# unit_122_output.json           → 14 chunks
# unit_123_output.json           → 14 chunks
# unit_124_output.json           → 12 chunks
# unit_125_output.json           → 12 chunks
# unit_126_output.json           → 7 chunks
# unit_127_output.json           → 10 chunks
# unit_128_output.json           → 12 chunks
# unit_129_output.json           → 13 chunks
# unit_130_output.json           → 10 chunks
# unit_131_output.json           → 12 chunks
# unit_132_output.json           → 7 chunks
# unit_133_output.json           → 10 chunks
# unit_APP1_output.json          → 12 chunks
# unit_APP2_output.json          → 8 chunks
# unit_z2_output.json            → 2 chunks
